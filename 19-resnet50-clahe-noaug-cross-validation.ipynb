# %%
import os
import gc
import time
import random
from pathlib import Path

import cv2
import kagglehub
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow version:", tf.__version__)
print("OpenCV version:", cv2.__version__)
print("Available GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow version: 2.20.0
# OpenCV version: 4.13.0
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
dataset_path = Path(
    kagglehub.dataset_download(
        "aryansinghal10/alzheimers-multiclass-dataset-equal-and-augmented"
    )
)

image_root = dataset_path / "combined_images"

print("Dataset path:", dataset_path)
print("Image folder:", image_root)
print("Image folder exists:", image_root.exists())
# Out:
# Dataset path: /kaggle/input/datasets/aryansinghal10/alzheimers-multiclass-dataset-equal-and-augmented
# Image folder: /kaggle/input/datasets/aryansinghal10/alzheimers-multiclass-dataset-equal-and-augmented/combined_images
# Image folder exists: True

# %%
class_to_binary = {
    "NonDemented": 0,
    "VeryMildDemented": 1,
    "MildDemented": 1,
    "ModerateDemented": 1
}

records = []

for class_name, binary_label in class_to_binary.items():
    class_folder = image_root / class_name

    for image_path in sorted(class_folder.iterdir()):
        if image_path.suffix.lower() in {".jpg", ".jpeg", ".png"}:
            records.append({
                "filepath": str(image_path),
                "original_class": class_name,
                "label": binary_label
            })

df = pd.DataFrame(records)

print("Total images:", len(df))
print("\nBinary class counts:")
print(df["label"].value_counts().sort_index())

print("\nOriginal class counts:")
print(df["original_class"].value_counts())
# Out:
# Total images: 44000
#
# Binary class counts:
# label
# 0    12800
# 1    31200
# Name: count, dtype: int64
#
# Original class counts:
# original_class
# NonDemented         12800
# VeryMildDemented    11200
# MildDemented        10000
# ModerateDemented    10000
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

initial_train_df, temporary_df = train_test_split(
    df,
    test_size=0.30,
    stratify=df["label"],
    random_state=SEED
)

initial_validation_df, test_df = train_test_split(
    temporary_df,
    test_size=0.50,
    stratify=temporary_df["label"],
    random_state=SEED
)

development_df = pd.concat(
    [initial_train_df, initial_validation_df],
    ignore_index=True
)

development_df = development_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

print("Development images:", len(development_df))
print(development_df["label"].value_counts().sort_index())

print("\nUntouched test images:", len(test_df))
print(test_df["label"].value_counts().sort_index())
# Out:
# Development images: 37400
# label
# 0    10880
# 1    26520
# Name: count, dtype: int64
#
# Untouched test images: 6600
# label
# 0    1920
# 1    4680
# Name: count, dtype: int64

# %%
CLAHE_CLIP_LIMIT = 2.0
CLAHE_TILE_SIZE = (8, 8)

clahe = cv2.createCLAHE(
    clipLimit=CLAHE_CLIP_LIMIT,
    tileGridSize=CLAHE_TILE_SIZE
)

sample_path = development_df.sample(
    1,
    random_state=SEED
)["filepath"].iloc[0]

original_image = cv2.imread(
    sample_path,
    cv2.IMREAD_GRAYSCALE
)

clahe_image = clahe.apply(original_image)

plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.imshow(original_image, cmap="gray")
plt.title("Original MRI")
plt.axis("off")

plt.subplot(2, 2, 2)
plt.imshow(clahe_image, cmap="gray")
plt.title("After CLAHE")
plt.axis("off")

plt.subplot(2, 2, 3)
plt.hist(original_image.ravel(), bins=256, color="gray")
plt.title("Original Intensity Histogram")
plt.xlabel("Pixel intensity")
plt.ylabel("Frequency")

plt.subplot(2, 2, 4)
plt.hist(clahe_image.ravel(), bins=256, color="darkorange")
plt.title("CLAHE Intensity Histogram")
plt.xlabel("Pixel intensity")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

print("CLAHE clip limit:", CLAHE_CLIP_LIMIT)
print("CLAHE tile size:", CLAHE_TILE_SIZE)
# Out:
# CLAHE clip limit: 2.0
# CLAHE tile size: (8, 8)

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

def apply_clahe(image):
    image = image.numpy()

    processor = cv2.createCLAHE(
        clipLimit=CLAHE_CLIP_LIMIT,
        tileGridSize=CLAHE_TILE_SIZE
    )

    return processor.apply(image)


def load_clahe_image(filepath, label):
    image = tf.io.read_file(filepath)

    image = tf.io.decode_image(
        image,
        channels=1,
        expand_animations=False
    )
    image.set_shape([None, None, 1])

    image = tf.squeeze(image, axis=-1)

    image = tf.py_function(
        apply_clahe,
        [image],
        Tout=tf.uint8
    )
    image.set_shape([None, None])

    image = tf.image.resize(
        image[..., tf.newaxis],
        IMG_SIZE
    )

    image = tf.image.grayscale_to_rgb(image)
    image = tf.cast(image, tf.float32)
    label = tf.cast(label, tf.float32)

    return image, label


def create_clahe_dataset(
    dataframe,
    training=False,
    shuffle_seed=SEED
):
    dataset = tf.data.Dataset.from_tensor_slices(
        (
            dataframe["filepath"].values,
            dataframe["label"].values
        )
    )

    if training:
        dataset = dataset.shuffle(
            buffer_size=min(len(dataframe), 10000),
            seed=shuffle_seed,
            reshuffle_each_iteration=True
        )

    dataset = dataset.map(
        load_clahe_image,
        num_parallel_calls=AUTOTUNE
    )

    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE)

    return dataset


test_dataset = create_clahe_dataset(test_df)

for images, labels in test_dataset.take(1):
    print("Image batch shape:", images.shape)
    print("Label batch shape:", labels.shape)
    print("Pixel range:", images.numpy().min(), "to", images.numpy().max())
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787762710.467522      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Image batch shape: (32, 224, 224, 3)
# Label batch shape: (32,)
# Pixel range: 1.0 to 255.0

# %%
from sklearn.model_selection import StratifiedKFold

MAX_EPOCHS = 30
PATIENCE = 5
LEARNING_RATE = 0.0001
N_FOLDS = 5

cross_validator = StratifiedKFold(
    n_splits=N_FOLDS,
    shuffle=True,
    random_state=SEED
)

for fold, (train_indices, validation_indices) in enumerate(
    cross_validator.split(
        development_df,
        development_df["label"]
    ),
    start=1
):
    fold_train_df = development_df.iloc[train_indices]
    fold_validation_df = development_df.iloc[validation_indices]

    print(
        f"Fold {fold}: "
        f"Training = {len(fold_train_df)}, "
        f"Validation = {len(fold_validation_df)}"
    )

print("\nMaximum epochs:", MAX_EPOCHS)
print("Early-stopping patience:", PATIENCE)
print("Learning rate:", LEARNING_RATE)
print("Preprocessing: CLAHE")
print("Augmentation: Disabled")
# Out:
# Fold 1: Training = 29920, Validation = 7480
# Fold 2: Training = 29920, Validation = 7480
# Fold 3: Training = 29920, Validation = 7480
# Fold 4: Training = 29920, Validation = 7480
# Fold 5: Training = 29920, Validation = 7480
#
# Maximum epochs: 30
# Early-stopping patience: 5
# Learning rate: 0.0001
# Preprocessing: CLAHE
# Augmentation: Disabled

# %%
def build_resnet50(fold_seed):
    tf.keras.utils.set_random_seed(fold_seed)

    resnet_base = tf.keras.applications.ResNet50(
        weights="imagenet",
        include_top=False,
        input_shape=(224, 224, 3)
    )

    resnet_base.trainable = False

    inputs = tf.keras.Input(shape=(224, 224, 3))

    x = tf.keras.applications.resnet50.preprocess_input(inputs)
    x = resnet_base(x, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.30)(x)

    outputs = tf.keras.layers.Dense(
        1,
        activation="sigmoid"
    )(x)

    model = tf.keras.Model(
        inputs=inputs,
        outputs=outputs,
        name="ResNet50_CLAHE_NoAug_CV"
    )

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=LEARNING_RATE
        ),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model


sample_model = build_resnet50(SEED)

print("Total parameters:", sample_model.count_params())
print(
    "Trainable parameters:",
    sum(
        tf.keras.backend.count_params(weight)
        for weight in sample_model.trainable_weights
    )
)
print(
    "ResNet50 frozen:",
    not sample_model.get_layer("resnet50").trainable
)

del sample_model
tf.keras.backend.clear_session()
gc.collect()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Total parameters: 23589761
# Trainable parameters: 2049
# ResNet50 frozen: True
# 0

# %%
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)

fold_histories = {}
fold_results = []
fold_test_probabilities = []
fold_model_paths = []

print("CLAHE cross-validation storage initialized.")
# Out:
# CLAHE cross-validation storage initialized.

# %%
for fold, (train_indices, validation_indices) in enumerate(
    cross_validator.split(
        development_df,
        development_df["label"]
    ),
    start=1
):
    print(
        f"\n{'=' * 20} "
        f"FOLD {fold}/{N_FOLDS} "
        f"{'=' * 20}"
    )

    fold_train_df = development_df.iloc[
        train_indices
    ].reset_index(drop=True)

    fold_validation_df = development_df.iloc[
        validation_indices
    ].reset_index(drop=True)

    train_dataset = create_clahe_dataset(
        fold_train_df,
        training=True,
        shuffle_seed=SEED + fold
    )

    validation_dataset = create_clahe_dataset(
        fold_validation_df
    )

    weights = compute_class_weight(
        class_weight="balanced",
        classes=np.array([0, 1]),
        y=fold_train_df["label"]
    )

    fold_class_weights = {
        0: float(weights[0]),
        1: float(weights[1])
    }

    tf.keras.backend.clear_session()
    gc.collect()

    model = build_resnet50(SEED + fold)

    model_path = (
        f"/kaggle/working/"
        f"resnet50_clahe_noaug_cv_fold_{fold}.keras"
    )

    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=PATIENCE,
            restore_best_weights=True,
            verbose=1
        ),

        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=2,
            min_lr=1e-7,
            verbose=1
        ),

        tf.keras.callbacks.ModelCheckpoint(
            model_path,
            monitor="val_loss",
            save_best_only=True,
            verbose=1
        )
    ]

    start_time = time.time()

    history = model.fit(
        train_dataset,
        validation_data=validation_dataset,
        epochs=MAX_EPOCHS,
        class_weight=fold_class_weights,
        callbacks=callbacks,
        verbose=1
    )

    training_minutes = (
        time.time() - start_time
    ) / 60

    history_df = pd.DataFrame(history.history)
    best_index = history_df["val_loss"].idxmin()

    fold_histories[fold] = history_df
    fold_model_paths.append(model_path)

    validation_probabilities = model.predict(
        validation_dataset,
        verbose=0
    ).ravel()

    validation_predictions = (
        validation_probabilities >= 0.5
    ).astype(int)

    validation_labels = fold_validation_df[
        "label"
    ].to_numpy()

    fold_results.append({
        "Fold": fold,
        "Epochs Trained": len(history_df),
        "Best Epoch": best_index + 1,
        "Training Loss": history_df.loc[
            best_index, "loss"
        ],
        "Training Accuracy": history_df.loc[
            best_index, "accuracy"
        ],
        "Validation Loss": history_df.loc[
            best_index, "val_loss"
        ],
        "Validation Accuracy": accuracy_score(
            validation_labels,
            validation_predictions
        ),
        "Precision": precision_score(
            validation_labels,
            validation_predictions
        ),
        "Recall": recall_score(
            validation_labels,
            validation_predictions
        ),
        "F1-score": f1_score(
            validation_labels,
            validation_predictions
        ),
        "ROC-AUC": roc_auc_score(
            validation_labels,
            validation_probabilities
        ),
        "Training Minutes": training_minutes
    })

    fold_test_probabilities.append(
        model.predict(
            test_dataset,
            verbose=0
        ).ravel()
    )

    print(
        f"Fold {fold} completed in "
        f"{training_minutes:.2f} minutes"
    )

    del model, train_dataset, validation_dataset
    tf.keras.backend.clear_session()
    gc.collect()
# Out:
# ==================== FOLD 1/5 ====================
# Epoch 1/30
#   4/935 ━━━━━━━━━━━━━━━━━━━━ 45s 49ms/step - accuracy: 0.4818 - loss: 0.9757
# I0000 00:00:1787762830.027610     142 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5579 - loss: 0.7497
# Epoch 1: val_loss improved from None to 0.53464, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_1.keras
#
# Epoch 1: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_1.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 138s 134ms/step - accuracy: 0.6159 - loss: 0.6792 - val_accuracy: 0.7425 - val_loss: 0.5346 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6887 - loss: 0.5906
# Epoch 2: val_loss improved from 0.53464 to 0.53185, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_1.keras
#
# Epoch 2: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_1.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.7040 - loss: 0.5749 - val_accuracy: 0.7432 - val_loss: 0.5319 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7247 - loss: 0.5458
# Epoch 3: val_loss improved from 0.53185 to 0.48644, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_1.keras
#
# Epoch 3: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_1.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.7322 - loss: 0.5342 - val_accuracy: 0.7697 - val_loss: 0.4864 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7440 - loss: 0.5203
# Epoch 4: val_loss did not improve from 0.48644
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 101s 107ms/step - accuracy: 0.7453 - loss: 0.5155 - val_accuracy: 0.7578 - val_loss: 0.4981 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7519 - loss: 0.5025
# Epoch 5: val_loss improved from 0.48644 to 0.47494, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_1.keras
#
# Epoch 5: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_1.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 101s 108ms/step - accuracy: 0.7538 - loss: 0.5009 - val_accuracy: 0.7757 - val_loss: 0.4749 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7585 - loss: 0.4896
# Epoch 6: val_loss did not improve from 0.47494
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 102s 109ms/step - accuracy: 0.7584 - loss: 0.4890 - val_accuracy: 0.7694 - val_loss: 0.4786 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7586 - loss: 0.4848
# Epoch 7: val_loss improved from 0.47494 to 0.43432, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_1.keras
#
# Epoch 7: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_1.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 111ms/step - accuracy: 0.7616 - loss: 0.4826 - val_accuracy: 0.8012 - val_loss: 0.4343 - learning_rate: 1.0000e-04
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7682 - loss: 0.4761
# Epoch 8: val_loss did not improve from 0.43432
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 101s 108ms/step - accuracy: 0.7657 - loss: 0.4772 - val_accuracy: 0.7981 - val_loss: 0.4381 - learning_rate: 1.0000e-04
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7701 - loss: 0.4779
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 9: val_loss did not improve from 0.43432
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 102s 109ms/step - accuracy: 0.7713 - loss: 0.4717 - val_accuracy: 0.7876 - val_loss: 0.4480 - learning_rate: 1.0000e-04
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7748 - loss: 0.4636
# Epoch 10: val_loss did not improve from 0.43432
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.7723 - loss: 0.4653 - val_accuracy: 0.7769 - val_loss: 0.4654 - learning_rate: 5.0000e-05
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7725 - loss: 0.4678
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 11: val_loss did not improve from 0.43432
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 101s 108ms/step - accuracy: 0.7725 - loss: 0.4664 - val_accuracy: 0.7767 - val_loss: 0.4653 - learning_rate: 5.0000e-05
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7757 - loss: 0.4633
# Epoch 12: val_loss did not improve from 0.43432
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.7752 - loss: 0.4634 - val_accuracy: 0.7817 - val_loss: 0.4557 - learning_rate: 2.5000e-05
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Fold 1 completed in 20.93 minutes
#
# ==================== FOLD 2/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5902 - loss: 0.7190
# Epoch 1: val_loss improved from None to 0.50817, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_2.keras
#
# Epoch 1: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_2.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 119s 116ms/step - accuracy: 0.6323 - loss: 0.6627 - val_accuracy: 0.7683 - val_loss: 0.5082 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7056 - loss: 0.5750
# Epoch 2: val_loss improved from 0.50817 to 0.48086, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_2.keras
#
# Epoch 2: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_2.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 102s 109ms/step - accuracy: 0.7126 - loss: 0.5641 - val_accuracy: 0.7739 - val_loss: 0.4809 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7366 - loss: 0.5358
# Epoch 3: val_loss did not improve from 0.48086
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.7364 - loss: 0.5317 - val_accuracy: 0.7619 - val_loss: 0.4900 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7500 - loss: 0.5151
# Epoch 4: val_loss improved from 0.48086 to 0.46860, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_2.keras
#
# Epoch 4: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_2.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 102s 109ms/step - accuracy: 0.7475 - loss: 0.5152 - val_accuracy: 0.7753 - val_loss: 0.4686 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7477 - loss: 0.5096
# Epoch 5: val_loss improved from 0.46860 to 0.46026, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_2.keras
#
# Epoch 5: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_2.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.7510 - loss: 0.5047 - val_accuracy: 0.7785 - val_loss: 0.4603 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7564 - loss: 0.4900
# Epoch 6: val_loss improved from 0.46026 to 0.44152, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_2.keras
#
# Epoch 6: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_2.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 111ms/step - accuracy: 0.7583 - loss: 0.4906 - val_accuracy: 0.7893 - val_loss: 0.4415 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7653 - loss: 0.4846
# Epoch 7: val_loss did not improve from 0.44152
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 111ms/step - accuracy: 0.7653 - loss: 0.4843 - val_accuracy: 0.7481 - val_loss: 0.5063 - learning_rate: 1.0000e-04
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7640 - loss: 0.4789
# Epoch 8: val_loss improved from 0.44152 to 0.43623, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_2.keras
#
# Epoch 8: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_2.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 104s 111ms/step - accuracy: 0.7656 - loss: 0.4766 - val_accuracy: 0.7941 - val_loss: 0.4362 - learning_rate: 1.0000e-04
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7724 - loss: 0.4735
# Epoch 9: val_loss did not improve from 0.43623
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 101s 108ms/step - accuracy: 0.7682 - loss: 0.4750 - val_accuracy: 0.7889 - val_loss: 0.4446 - learning_rate: 1.0000e-04
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7698 - loss: 0.4697
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 10: val_loss did not improve from 0.43623
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.7709 - loss: 0.4689 - val_accuracy: 0.7806 - val_loss: 0.4550 - learning_rate: 1.0000e-04
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7701 - loss: 0.4713
# Epoch 11: val_loss did not improve from 0.43623
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.7734 - loss: 0.4664 - val_accuracy: 0.7873 - val_loss: 0.4467 - learning_rate: 5.0000e-05
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7735 - loss: 0.4670
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 12: val_loss did not improve from 0.43623
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 101s 108ms/step - accuracy: 0.7742 - loss: 0.4646 - val_accuracy: 0.7918 - val_loss: 0.4372 - learning_rate: 5.0000e-05
# Epoch 13/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7748 - loss: 0.4613
# Epoch 13: val_loss improved from 0.43623 to 0.43296, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_2.keras
#
# Epoch 13: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_2.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 104s 112ms/step - accuracy: 0.7750 - loss: 0.4612 - val_accuracy: 0.7949 - val_loss: 0.4330 - learning_rate: 2.5000e-05
# Epoch 14/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7743 - loss: 0.4625
# Epoch 14: val_loss did not improve from 0.43296
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.7741 - loss: 0.4636 - val_accuracy: 0.7889 - val_loss: 0.4440 - learning_rate: 2.5000e-05
# Epoch 15/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7783 - loss: 0.4605
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 15: val_loss did not improve from 0.43296
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 104s 111ms/step - accuracy: 0.7768 - loss: 0.4604 - val_accuracy: 0.7897 - val_loss: 0.4427 - learning_rate: 2.5000e-05
# Epoch 16/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7790 - loss: 0.4589
# Epoch 16: val_loss did not improve from 0.43296
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 104s 111ms/step - accuracy: 0.7775 - loss: 0.4603 - val_accuracy: 0.7894 - val_loss: 0.4417 - learning_rate: 1.2500e-05
# Epoch 17/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7737 - loss: 0.4635
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 17: val_loss did not improve from 0.43296
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 102s 109ms/step - accuracy: 0.7759 - loss: 0.4606 - val_accuracy: 0.7864 - val_loss: 0.4466 - learning_rate: 1.2500e-05
# Epoch 18/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7786 - loss: 0.4590
# Epoch 18: val_loss did not improve from 0.43296
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.7803 - loss: 0.4588 - val_accuracy: 0.7894 - val_loss: 0.4421 - learning_rate: 6.2500e-06
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Fold 2 completed in 31.02 minutes
#
# ==================== FOLD 3/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5443 - loss: 0.7758
# Epoch 1: val_loss improved from None to 0.55100, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_3.keras
#
# Epoch 1: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_3.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 122s 119ms/step - accuracy: 0.6048 - loss: 0.6996 - val_accuracy: 0.7290 - val_loss: 0.5510 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6948 - loss: 0.5894
# Epoch 2: val_loss improved from 0.55100 to 0.50306, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_3.keras
#
# Epoch 2: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_3.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 112ms/step - accuracy: 0.7017 - loss: 0.5805 - val_accuracy: 0.7599 - val_loss: 0.5031 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7271 - loss: 0.5480
# Epoch 3: val_loss improved from 0.50306 to 0.46284, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_3.keras
#
# Epoch 3: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_3.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 104s 111ms/step - accuracy: 0.7309 - loss: 0.5395 - val_accuracy: 0.7880 - val_loss: 0.4628 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7446 - loss: 0.5214
# Epoch 4: val_loss did not improve from 0.46284
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 102s 110ms/step - accuracy: 0.7461 - loss: 0.5189 - val_accuracy: 0.7439 - val_loss: 0.5080 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7512 - loss: 0.5068
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 5: val_loss did not improve from 0.46284
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 111ms/step - accuracy: 0.7508 - loss: 0.5054 - val_accuracy: 0.7738 - val_loss: 0.4738 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7604 - loss: 0.4923
# Epoch 6: val_loss did not improve from 0.46284
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 112ms/step - accuracy: 0.7580 - loss: 0.4936 - val_accuracy: 0.7777 - val_loss: 0.4665 - learning_rate: 5.0000e-05
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7630 - loss: 0.4879
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 7: val_loss did not improve from 0.46284
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 104s 111ms/step - accuracy: 0.7624 - loss: 0.4890 - val_accuracy: 0.7682 - val_loss: 0.4761 - learning_rate: 5.0000e-05
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7637 - loss: 0.4818
# Epoch 8: val_loss did not improve from 0.46284
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 112ms/step - accuracy: 0.7640 - loss: 0.4842 - val_accuracy: 0.7683 - val_loss: 0.4765 - learning_rate: 2.5000e-05
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Fold 3 completed in 14.17 minutes
#
# ==================== FOLD 4/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5819 - loss: 0.7094
# Epoch 1: val_loss improved from None to 0.51756, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_4.keras
#
# Epoch 1: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_4.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 125s 121ms/step - accuracy: 0.6279 - loss: 0.6578 - val_accuracy: 0.7567 - val_loss: 0.5176 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7072 - loss: 0.5779
# Epoch 2: val_loss improved from 0.51756 to 0.50803, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_4.keras
#
# Epoch 2: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_4.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 112ms/step - accuracy: 0.7110 - loss: 0.5675 - val_accuracy: 0.7588 - val_loss: 0.5080 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7240 - loss: 0.5456
# Epoch 3: val_loss improved from 0.50803 to 0.48864, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_4.keras
#
# Epoch 3: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_4.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 112ms/step - accuracy: 0.7318 - loss: 0.5328 - val_accuracy: 0.7703 - val_loss: 0.4886 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7440 - loss: 0.5199
# Epoch 4: val_loss improved from 0.48864 to 0.46434, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_4.keras
#
# Epoch 4: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_4.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 112ms/step - accuracy: 0.7486 - loss: 0.5123 - val_accuracy: 0.7881 - val_loss: 0.4643 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7528 - loss: 0.5034
# Epoch 5: val_loss did not improve from 0.46434
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 104s 111ms/step - accuracy: 0.7549 - loss: 0.5005 - val_accuracy: 0.7632 - val_loss: 0.4901 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7533 - loss: 0.4965
# Epoch 6: val_loss improved from 0.46434 to 0.45383, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_4.keras
#
# Epoch 6: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_4.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 113ms/step - accuracy: 0.7584 - loss: 0.4918 - val_accuracy: 0.7904 - val_loss: 0.4538 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7637 - loss: 0.4838
# Epoch 7: val_loss did not improve from 0.45383
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 112ms/step - accuracy: 0.7634 - loss: 0.4838 - val_accuracy: 0.7864 - val_loss: 0.4545 - learning_rate: 1.0000e-04
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7703 - loss: 0.4748
# Epoch 8: val_loss improved from 0.45383 to 0.43896, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_4.keras
#
# Epoch 8: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_4.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 114ms/step - accuracy: 0.7675 - loss: 0.4771 - val_accuracy: 0.7973 - val_loss: 0.4390 - learning_rate: 1.0000e-04
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7692 - loss: 0.4781
# Epoch 9: val_loss did not improve from 0.43896
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 113ms/step - accuracy: 0.7693 - loss: 0.4748 - val_accuracy: 0.7876 - val_loss: 0.4508 - learning_rate: 1.0000e-04
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7717 - loss: 0.4747
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 10: val_loss did not improve from 0.43896
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 112ms/step - accuracy: 0.7728 - loss: 0.4692 - val_accuracy: 0.7951 - val_loss: 0.4409 - learning_rate: 1.0000e-04
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7750 - loss: 0.4664
# Epoch 11: val_loss did not improve from 0.43896
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7750 - loss: 0.4651 - val_accuracy: 0.7779 - val_loss: 0.4651 - learning_rate: 5.0000e-05
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7741 - loss: 0.4673
# Epoch 12: val_loss improved from 0.43896 to 0.43320, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_4.keras
#
# Epoch 12: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_4.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7748 - loss: 0.4646 - val_accuracy: 0.7983 - val_loss: 0.4332 - learning_rate: 5.0000e-05
# Epoch 13/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7778 - loss: 0.4602
# Epoch 13: val_loss did not improve from 0.43320
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 114ms/step - accuracy: 0.7757 - loss: 0.4625 - val_accuracy: 0.7904 - val_loss: 0.4466 - learning_rate: 5.0000e-05
# Epoch 14/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7799 - loss: 0.4593
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 14: val_loss did not improve from 0.43320
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 112ms/step - accuracy: 0.7777 - loss: 0.4619 - val_accuracy: 0.7816 - val_loss: 0.4599 - learning_rate: 5.0000e-05
# Epoch 15/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7736 - loss: 0.4637
# Epoch 15: val_loss did not improve from 0.43320
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 112ms/step - accuracy: 0.7766 - loss: 0.4591 - val_accuracy: 0.7934 - val_loss: 0.4397 - learning_rate: 2.5000e-05
# Epoch 16/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7821 - loss: 0.4570
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 16: val_loss did not improve from 0.43320
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7778 - loss: 0.4598 - val_accuracy: 0.7857 - val_loss: 0.4536 - learning_rate: 2.5000e-05
# Epoch 17/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7808 - loss: 0.4535
# Epoch 17: val_loss did not improve from 0.43320
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 104s 111ms/step - accuracy: 0.7782 - loss: 0.4568 - val_accuracy: 0.7858 - val_loss: 0.4534 - learning_rate: 1.2500e-05
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Fold 4 completed in 30.18 minutes
#
# ==================== FOLD 5/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5600 - loss: 0.7291
# Epoch 1: val_loss improved from None to 0.53769, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
#
# Epoch 1: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 123s 119ms/step - accuracy: 0.6159 - loss: 0.6715 - val_accuracy: 0.7439 - val_loss: 0.5377 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6915 - loss: 0.5885
# Epoch 2: val_loss improved from 0.53769 to 0.51317, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
#
# Epoch 2: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7072 - loss: 0.5693 - val_accuracy: 0.7543 - val_loss: 0.5132 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7262 - loss: 0.5453
# Epoch 3: val_loss improved from 0.51317 to 0.47976, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
#
# Epoch 3: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 112ms/step - accuracy: 0.7309 - loss: 0.5361 - val_accuracy: 0.7758 - val_loss: 0.4798 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7465 - loss: 0.5124
# Epoch 4: val_loss did not improve from 0.47976
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 104s 111ms/step - accuracy: 0.7456 - loss: 0.5142 - val_accuracy: 0.7723 - val_loss: 0.4810 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7538 - loss: 0.5015
# Epoch 5: val_loss improved from 0.47976 to 0.45921, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
#
# Epoch 5: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7539 - loss: 0.5005 - val_accuracy: 0.7861 - val_loss: 0.4592 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7611 - loss: 0.4919
# Epoch 6: val_loss did not improve from 0.45921
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.7605 - loss: 0.4927 - val_accuracy: 0.7787 - val_loss: 0.4723 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7611 - loss: 0.4865
# Epoch 7: val_loss improved from 0.45921 to 0.45696, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
#
# Epoch 7: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.7640 - loss: 0.4828 - val_accuracy: 0.7868 - val_loss: 0.4570 - learning_rate: 1.0000e-04
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7632 - loss: 0.4813
# Epoch 8: val_loss improved from 0.45696 to 0.45643, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
#
# Epoch 8: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.7662 - loss: 0.4794 - val_accuracy: 0.7864 - val_loss: 0.4564 - learning_rate: 1.0000e-04
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7725 - loss: 0.4729
# Epoch 9: val_loss improved from 0.45643 to 0.44277, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
#
# Epoch 9: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.7697 - loss: 0.4749 - val_accuracy: 0.7940 - val_loss: 0.4428 - learning_rate: 1.0000e-04
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7755 - loss: 0.4687
# Epoch 10: val_loss did not improve from 0.44277
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.7734 - loss: 0.4715 - val_accuracy: 0.7676 - val_loss: 0.4767 - learning_rate: 1.0000e-04
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7745 - loss: 0.4675
# Epoch 11: val_loss improved from 0.44277 to 0.44220, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
#
# Epoch 11: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 101s 108ms/step - accuracy: 0.7744 - loss: 0.4690 - val_accuracy: 0.7940 - val_loss: 0.4422 - learning_rate: 1.0000e-04
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7789 - loss: 0.4627
# Epoch 12: val_loss improved from 0.44220 to 0.43188, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
#
# Epoch 12: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.7775 - loss: 0.4635 - val_accuracy: 0.8007 - val_loss: 0.4319 - learning_rate: 1.0000e-04
# Epoch 13/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7750 - loss: 0.4664
# Epoch 13: val_loss improved from 0.43188 to 0.42040, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
#
# Epoch 13: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 101s 108ms/step - accuracy: 0.7762 - loss: 0.4632 - val_accuracy: 0.8079 - val_loss: 0.4204 - learning_rate: 1.0000e-04
# Epoch 14/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7789 - loss: 0.4635
# Epoch 14: val_loss did not improve from 0.42040
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.7796 - loss: 0.4598 - val_accuracy: 0.7837 - val_loss: 0.4511 - learning_rate: 1.0000e-04
# Epoch 15/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7836 - loss: 0.4531
# Epoch 15: val_loss improved from 0.42040 to 0.41189, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
#
# Epoch 15: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.7787 - loss: 0.4567 - val_accuracy: 0.8104 - val_loss: 0.4119 - learning_rate: 1.0000e-04
# Epoch 16/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7852 - loss: 0.4526
# Epoch 16: val_loss did not improve from 0.41189
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 101s 108ms/step - accuracy: 0.7787 - loss: 0.4571 - val_accuracy: 0.7774 - val_loss: 0.4595 - learning_rate: 1.0000e-04
# Epoch 17/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7796 - loss: 0.4541
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 17: val_loss did not improve from 0.41189
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.7810 - loss: 0.4553 - val_accuracy: 0.7735 - val_loss: 0.4660 - learning_rate: 1.0000e-04
# Epoch 18/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.7799 - loss: 0.4550
# Epoch 18: val_loss did not improve from 0.41189
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 148s 158ms/step - accuracy: 0.7818 - loss: 0.4520 - val_accuracy: 0.8001 - val_loss: 0.4263 - learning_rate: 5.0000e-05
# Epoch 19/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7860 - loss: 0.4516
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 19: val_loss improved from 0.41189 to 0.41183, saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
#
# Epoch 19: finished saving model to /kaggle/working/resnet50_clahe_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 102s 109ms/step - accuracy: 0.7856 - loss: 0.4505 - val_accuracy: 0.8119 - val_loss: 0.4118 - learning_rate: 5.0000e-05
# Epoch 20/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7845 - loss: 0.4489
# Epoch 20: val_loss did not improve from 0.41183
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.7824 - loss: 0.4504 - val_accuracy: 0.7856 - val_loss: 0.4460 - learning_rate: 2.5000e-05
# Epoch 21/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7828 - loss: 0.4480
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 21: val_loss did not improve from 0.41183
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.7837 - loss: 0.4501 - val_accuracy: 0.8005 - val_loss: 0.4254 - learning_rate: 2.5000e-05
# Epoch 22/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7794 - loss: 0.4551
# Epoch 22: val_loss did not improve from 0.41183
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.7836 - loss: 0.4486 - val_accuracy: 0.7957 - val_loss: 0.4312 - learning_rate: 1.2500e-05
# Epoch 23/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7898 - loss: 0.4461
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 23: val_loss did not improve from 0.41183
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.7870 - loss: 0.4478 - val_accuracy: 0.8029 - val_loss: 0.4223 - learning_rate: 1.2500e-05
# Epoch 24/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7856 - loss: 0.4474
# Epoch 24: val_loss did not improve from 0.41183
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.7839 - loss: 0.4474 - val_accuracy: 0.8028 - val_loss: 0.4232 - learning_rate: 6.2500e-06
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Fold 5 completed in 41.96 minutes

# %%
fold_results_df = pd.DataFrame(fold_results)

display(
    fold_results_df.round(4)
)

print(
    "\nMean validation accuracy:",
    round(
        fold_results_df[
            "Validation Accuracy"
        ].mean(),
        4
    )
)

print(
    "Validation accuracy standard deviation:",
    round(
        fold_results_df[
            "Validation Accuracy"
        ].std(),
        4
    )
)

print(
    "Mean validation ROC-AUC:",
    round(
        fold_results_df[
            "ROC-AUC"
        ].mean(),
        4
    )
)
# Out:
#    Fold  Epochs Trained  Best Epoch  Training Loss  Training Accuracy  \
# 0     1              12           7         0.4826             0.7616
# 1     2              18          13         0.4612             0.7750
# 2     3               8           3         0.5395             0.7309
# 3     4              17          12         0.4646             0.7748
# 4     5              24          19         0.4505             0.7856
#
#    Validation Loss  Validation Accuracy  Precision  Recall  F1-score  ROC-AUC  \
# 0           0.4343               0.8012     0.8765  0.8377    0.8566   0.8623
# 1           0.4330               0.7949     0.8921  0.8086    0.8483   0.8767
# 2           0.4628               0.7880     0.8731  0.8201    0.8458   0.8466
# 3           0.4332               0.7983     0.8921  0.8139    0.8512   0.8750
# 4           0.4118               0.8119     0.9012  0.8252    0.8615   0.8877
#
#    Training Minutes
# 0           20.9341
# 1           31.0170
# 2           14.1685
# 3           30.1847
# 4           41.9645
# Mean validation accuracy: 0.7989
# Validation accuracy standard deviation: 0.0088
# Mean validation ROC-AUC: 0.8697

# %%
summary_columns = [
    "Training Loss",
    "Training Accuracy",
    "Validation Loss",
    "Validation Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "ROC-AUC",
    "Training Minutes"
]

cv_summary = pd.DataFrame({
    "Mean": fold_results_df[
        summary_columns
    ].mean(),

    "Standard Deviation": fold_results_df[
        summary_columns
    ].std()
})

display(cv_summary.round(4))
# Out:
#                         Mean  Standard Deviation
# Training Loss         0.4797              0.0354
# Training Accuracy     0.7656              0.0211
# Validation Loss       0.4350              0.0182
# Validation Accuracy   0.7989              0.0088
# Precision             0.8870              0.0118
# Recall                0.8211              0.0112
# F1-score              0.8527              0.0064
# ROC-AUC               0.8697              0.0157
# Training Minutes     27.6538             10.6010

# %%
test_probabilities_cv = np.mean(
    np.vstack(fold_test_probabilities),
    axis=0
)

test_predictions_cv = (
    test_probabilities_cv >= 0.5
).astype(int)

true_test_labels = test_df[
    "label"
].to_numpy()

print("Test images:", len(true_test_labels))
print("Fold prediction arrays:", len(fold_test_probabilities))
print("Ensemble probabilities:", len(test_probabilities_cv))
print("Ensemble predictions:", len(test_predictions_cv))

print(
    "First ensemble probabilities:",
    test_probabilities_cv[:10].round(4)
)
# Out:
# Test images: 6600
# Fold prediction arrays: 5
# Ensemble probabilities: 6600
# Ensemble predictions: 6600
# First ensemble probabilities: [0.8683 0.6481 0.8818 0.571  0.7986 0.8839 0.6455 0.3348 0.9613 0.9026]

# %%
from sklearn.metrics import log_loss

test_loss_cv = log_loss(
    true_test_labels,
    test_probabilities_cv
)

test_accuracy_cv = accuracy_score(
    true_test_labels,
    test_predictions_cv
)

print("Test Loss:", round(test_loss_cv, 4))
print("Test Accuracy:", round(test_accuracy_cv, 4))
# Out:
# Test Loss: 0.4398
# Test Accuracy: 0.7961

# %%
from sklearn.metrics import classification_report

test_precision_cv = precision_score(
    true_test_labels,
    test_predictions_cv
)

test_recall_cv = recall_score(
    true_test_labels,
    test_predictions_cv
)

test_f1_cv = f1_score(
    true_test_labels,
    test_predictions_cv
)

test_roc_auc_cv = roc_auc_score(
    true_test_labels,
    test_probabilities_cv
)

print("Test Loss:", round(test_loss_cv, 4))
print("Accuracy:", round(test_accuracy_cv, 4))
print("Precision:", round(test_precision_cv, 4))
print("Recall:", round(test_recall_cv, 4))
print("F1-score:", round(test_f1_cv, 4))
print("ROC-AUC:", round(test_roc_auc_cv, 4))

print("\nClassification Report:\n")
print(
    classification_report(
        true_test_labels,
        test_predictions_cv,
        target_names=["NonDemented", "Demented"],
        digits=4
    )
)
# Out:
# Test Loss: 0.4398
# Accuracy: 0.7961
# Precision: 0.8862
# Recall: 0.8173
# F1-score: 0.8504
# ROC-AUC: 0.867
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#  NonDemented     0.6257    0.7443    0.6798      1920
#     Demented     0.8862    0.8173    0.8504      4680
#
#     accuracy                         0.7961      6600
#    macro avg     0.7559    0.7808    0.7651      6600
# weighted avg     0.8104    0.7961    0.8008      6600

# %%
from sklearn.metrics import confusion_matrix

confusion_cv = confusion_matrix(
    true_test_labels,
    test_predictions_cv
)

plt.figure(figsize=(7, 5))

sns.heatmap(
    confusion_cv,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["NonDemented", "Demented"],
    yticklabels=["NonDemented", "Demented"]
)

plt.title(
    "ResNet50 CLAHE Without Augmentation\n"
    "5-Fold CV Ensemble Confusion Matrix"
)
plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve

false_positive_rate, true_positive_rate, thresholds = roc_curve(
    true_test_labels,
    test_probabilities_cv
)

plt.figure(figsize=(7, 5))

plt.plot(
    false_positive_rate,
    true_positive_rate,
    linewidth=2,
    label=(
        "CLAHE Without Augmentation "
        f"(AUC = {test_roc_auc_cv:.4f})"
    )
)

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--",
    color="gray",
    label="Random Classifier"
)

plt.title(
    "ResNet50 CLAHE Without Augmentation\n"
    "5-Fold CV Ensemble ROC Curve"
)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
mean_validation_accuracy = fold_results_df[
    "Validation Accuracy"
].mean()

plt.figure(figsize=(8, 5))

bars = plt.bar(
    fold_results_df["Fold"],
    fold_results_df["Validation Accuracy"],
    color="darkorange"
)

plt.axhline(
    mean_validation_accuracy,
    color="red",
    linestyle="--",
    label=f"Mean = {mean_validation_accuracy:.4f}"
)

for bar, value in zip(
    bars,
    fold_results_df["Validation Accuracy"]
):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        value + 0.003,
        f"{value:.4f}",
        ha="center"
    )

plt.ylim(0, 1)
plt.title(
    "ResNet50 CLAHE Without Augmentation\n"
    "Validation Accuracy Across Five Folds"
)
plt.xlabel("Fold")
plt.ylabel("Validation Accuracy")
plt.xticks(fold_results_df["Fold"])
plt.legend()
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Individual loss graph for each fold
fig, axes = plt.subplots(
    2,
    3,
    figsize=(15, 9),
    sharey=True
)

axes = axes.flatten()

for index, (fold, fold_history) in enumerate(
    fold_histories.items()
):
    ax = axes[index]

    epochs = np.arange(1, len(fold_history) + 1)
    best_epoch_fold = fold_history["val_loss"].idxmin() + 1
    best_val_loss = fold_history["val_loss"].min()

    ax.plot(
        epochs,
        fold_history["loss"],
        color="steelblue",
        linewidth=2,
        label="Training Loss"
    )

    ax.plot(
        epochs,
        fold_history["val_loss"],
        color="darkorange",
        linewidth=2,
        label="Validation Loss"
    )

    ax.axvline(
        best_epoch_fold,
        color="red",
        linestyle="--",
        label=f"Best Epoch: {best_epoch_fold}"
    )

    ax.scatter(
        best_epoch_fold,
        best_val_loss,
        color="red",
        s=60,
        zorder=5
    )

    ax.set_title(f"Fold {fold}")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.grid(alpha=0.3)
    ax.legend(fontsize=8)

fig.delaxes(axes[5])

plt.suptitle(
    "ResNet50 CLAHE Without Augmentation\n"
    "Training and Validation Loss by Fold",
    fontsize=16
)

plt.tight_layout()
plt.show()


# All folds together
plt.figure(figsize=(12, 7))

colors = [
    "tab:blue",
    "tab:green",
    "tab:purple",
    "tab:pink",
    "tab:olive"
]

for (fold, fold_history), color in zip(
    fold_histories.items(),
    colors
):
    epochs = range(1, len(fold_history) + 1)

    plt.plot(
        epochs,
        fold_history["loss"],
        color=color,
        linewidth=2,
        label=f"Fold {fold} Training"
    )

    plt.plot(
        epochs,
        fold_history["val_loss"],
        color=color,
        linestyle="--",
        linewidth=2,
        label=f"Fold {fold} Validation"
    )

plt.title(
    "ResNet50 CLAHE Without Augmentation\n"
    "Training and Validation Loss Across All Five Folds"
)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(ncol=2, fontsize=9)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Individual accuracy graph for each fold
fig, axes = plt.subplots(
    2,
    3,
    figsize=(15, 9),
    sharey=True
)

axes = axes.flatten()

for index, (fold, fold_history) in enumerate(
    fold_histories.items()
):
    ax = axes[index]

    epochs = np.arange(1, len(fold_history) + 1)
    best_epoch_fold = fold_history["val_loss"].idxmin() + 1

    ax.plot(
        epochs,
        fold_history["accuracy"],
        color="steelblue",
        linewidth=2,
        label="Training Accuracy"
    )

    ax.plot(
        epochs,
        fold_history["val_accuracy"],
        color="darkorange",
        linewidth=2,
        label="Validation Accuracy"
    )

    ax.axvline(
        best_epoch_fold,
        color="red",
        linestyle="--",
        label=f"Best Epoch: {best_epoch_fold}"
    )

    ax.set_title(f"Fold {fold}")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Accuracy")
    ax.set_ylim(0.55, 0.85)
    ax.grid(alpha=0.3)
    ax.legend(fontsize=8)

fig.delaxes(axes[5])

plt.suptitle(
    "ResNet50 CLAHE Without Augmentation\n"
    "Training and Validation Accuracy by Fold",
    fontsize=16
)

plt.tight_layout()
plt.show()


# All folds together
plt.figure(figsize=(12, 7))

colors = [
    "tab:blue",
    "tab:green",
    "tab:purple",
    "tab:pink",
    "tab:olive"
]

for (fold, fold_history), color in zip(
    fold_histories.items(),
    colors
):
    epochs = range(1, len(fold_history) + 1)

    plt.plot(
        epochs,
        fold_history["accuracy"],
        color=color,
        linewidth=2,
        label=f"Fold {fold} Training"
    )

    plt.plot(
        epochs,
        fold_history["val_accuracy"],
        color=color,
        linestyle="--",
        linewidth=2,
        label=f"Fold {fold} Validation"
    )

plt.title(
    "ResNet50 CLAHE Without Augmentation\n"
    "Training and Validation Accuracy Across All Five Folds"
)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(ncol=2, fontsize=9)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
metric_names = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "ROC-AUC"
]

metric_values = [
    test_accuracy_cv,
    test_precision_cv,
    test_recall_cv,
    test_f1_cv,
    test_roc_auc_cv
]

plt.figure(figsize=(9, 5))

bars = plt.bar(
    metric_names,
    metric_values,
    color=[
        "steelblue",
        "teal",
        "darkorange",
        "purple",
        "seagreen"
    ]
)

plt.ylim(0, 1)
plt.title(
    "ResNet50 CLAHE Without Augmentation\n"
    "5-Fold CV Ensemble Test Metrics"
)
plt.ylabel("Score")
plt.grid(axis="y", alpha=0.3)

for bar, value in zip(bars, metric_values):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        value + 0.015,
        f"{value:.4f}",
        ha="center"
    )

plt.tight_layout()
plt.show()

# %%
sample_indices = np.random.default_rng(SEED).choice(
    len(test_df),
    size=12,
    replace=False
)

plt.figure(figsize=(16, 12))

for position, index in enumerate(sample_indices, start=1):
    original = cv2.imread(
        test_df.iloc[index]["filepath"],
        cv2.IMREAD_GRAYSCALE
    )

    processor = cv2.createCLAHE(
        clipLimit=CLAHE_CLIP_LIMIT,
        tileGridSize=CLAHE_TILE_SIZE
    )

    processed = processor.apply(original)

    actual = true_test_labels[index]
    predicted = test_predictions_cv[index]
    probability = test_probabilities_cv[index]

    actual_name = (
        "Demented" if actual == 1
        else "NonDemented"
    )

    predicted_name = (
        "Demented" if predicted == 1
        else "NonDemented"
    )

    title_color = (
        "green" if actual == predicted
        else "red"
    )

    plt.subplot(3, 4, position)
    plt.imshow(processed, cmap="gray")
    plt.title(
        f"Actual: {actual_name}\n"
        f"Predicted: {predicted_name}\n"
        f"Dementia probability: {probability:.3f}",
        color=title_color,
        fontsize=10
    )
    plt.axis("off")

plt.suptitle(
    "ResNet50 CLAHE Without Augmentation\n"
    "5-Fold CV Ensemble Sanity Test",
    fontsize=16
)

plt.tight_layout()
plt.show()

# %%
test_results_df = pd.DataFrame([{
    "Experiment": (
        "ResNet50 CLAHE Without Augmentation "
        "+ 5-Fold CV"
    ),
    "Model": "ResNet50",
    "Preprocessing": "CLAHE",
    "Augmentation": "No",
    "Cross-Validation": "5-Fold",
    "CLAHE Clip Limit": CLAHE_CLIP_LIMIT,
    "CLAHE Tile Size": str(CLAHE_TILE_SIZE),
    "Test Loss": test_loss_cv,
    "Accuracy": test_accuracy_cv,
    "Precision": test_precision_cv,
    "Recall": test_recall_cv,
    "F1-score": test_f1_cv,
    "ROC-AUC": test_roc_auc_cv
}])

fold_results_df.to_csv(
    "/kaggle/working/"
    "resnet50_clahe_noaug_cv_fold_results.csv",
    index=False
)

cv_summary.to_csv(
    "/kaggle/working/"
    "resnet50_clahe_noaug_cv_summary.csv"
)

test_results_df.to_csv(
    "/kaggle/working/"
    "resnet50_clahe_noaug_cv_test_results.csv",
    index=False
)

for fold, fold_history in fold_histories.items():
    fold_history.to_csv(
        f"/kaggle/working/"
        f"resnet50_clahe_noaug_cv_fold_{fold}_history.csv",
        index=False
    )

display(test_results_df.round(4))

print("Saved:")
print("- Fold results CSV")
print("- Mean and standard-deviation summary CSV")
print("- Ensemble test-results CSV")
print("- Five training-history CSV files")
print("- Five best CLAHE fold models")
# Out:
#                                         Experiment     Model Preprocessing  \
# 0  ResNet50 CLAHE Without Augmentation + 5-Fold CV  ResNet50         CLAHE
#
#   Augmentation Cross-Validation  CLAHE Clip Limit CLAHE Tile Size  Test Loss  \
# 0           No           5-Fold               2.0          (8, 8)     0.4398
#
#    Accuracy  Precision  Recall  F1-score  ROC-AUC
# 0    0.7961     0.8862  0.8173    0.8504    0.867
# Saved:
# - Fold results CSV
# - Mean and standard-deviation summary CSV
# - Ensemble test-results CSV
# - Five training-history CSV files
# - Five best CLAHE fold models
