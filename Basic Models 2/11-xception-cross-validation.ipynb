# %%
import os
import gc
import time
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import kagglehub

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow version:", tf.__version__)
print("Available GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow version: 2.20.0
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
dataset_path = Path(
    kagglehub.dataset_download(
        "aryansinghal10/alzheimers-multiclass-dataset-equal-and-augmented"
    )
)

image_root = dataset_path / "combined_images"

print("Dataset path:", dataset_path)
print("Image folder exists:", image_root.exists())
# Out:
# Dataset path: /kaggle/input/datasets/aryansinghal10/alzheimers-multiclass-dataset-equal-and-augmented
# Image folder exists: True

# %%
class_to_binary = {
    "NonDemented": 0,
    "VeryMildDemented": 1,
    "MildDemented": 1,
    "ModerateDemented": 1
}

records = []

for class_name, binary_label in class_to_binary.items():
    class_folder = image_root / class_name

    for image_path in sorted(class_folder.iterdir()):
        if image_path.suffix.lower() in {
            ".jpg", ".jpeg", ".png"
        }:
            records.append({
                "filepath": str(image_path),
                "original_class": class_name,
                "label": binary_label
            })

df = pd.DataFrame(records)

print("Total images:", len(df))
print(df["label"].value_counts().sort_index())
# Out:
# Total images: 44000
# label
# 0    12800
# 1    31200
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

development_df, test_df = train_test_split(
    df,
    test_size=0.15,
    stratify=df["label"],
    random_state=SEED
)

development_df = development_df.reset_index(
    drop=True
)

test_df = test_df.reset_index(
    drop=True
)

print("Development images:", len(development_df))
print(development_df["label"].value_counts().sort_index())

print("\nTest images:", len(test_df))
print(test_df["label"].value_counts().sort_index())
# Out:
# Development images: 37400
# label
# 0    10880
# 1    26520
# Name: count, dtype: int64
#
# Test images: 6600
# label
# 0    1920
# 1    4680
# Name: count, dtype: int64

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

def load_and_resize_image(filepath, label):
    image = tf.io.read_file(filepath)

    image = tf.io.decode_image(
        image,
        channels=3,
        expand_animations=False
    )

    image.set_shape([None, None, 3])
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.cast(image, tf.float32)
    label = tf.cast(label, tf.float32)

    return image, label


def create_dataset(
    dataframe,
    training=False,
    shuffle_seed=SEED
):
    dataset = tf.data.Dataset.from_tensor_slices(
        (
            dataframe["filepath"].values,
            dataframe["label"].values
        )
    )

    if training:
        dataset = dataset.shuffle(
            buffer_size=min(
                len(dataframe),
                10000
            ),
            seed=shuffle_seed,
            reshuffle_each_iteration=True
        )

    dataset = dataset.map(
        load_and_resize_image,
        num_parallel_calls=AUTOTUNE
    )

    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE)

    return dataset


test_dataset = create_dataset(test_df)

for images, labels in test_dataset.take(1):
    print("Image batch shape:", images.shape)
    print("Label batch shape:", labels.shape)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787590389.424917      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Image batch shape: (32, 224, 224, 3)
# Label batch shape: (32,)

# %%
from sklearn.model_selection import StratifiedKFold

MAX_EPOCHS = 30
PATIENCE = 5
LEARNING_RATE = 0.0001
N_FOLDS = 5

cross_validator = StratifiedKFold(
    n_splits=N_FOLDS,
    shuffle=True,
    random_state=SEED
)

for fold, (train_indices, validation_indices) in enumerate(
    cross_validator.split(
        development_df,
        development_df["label"]
    ),
    start=1
):
    print(
        f"Fold {fold}: "
        f"Training = {len(train_indices)}, "
        f"Validation = {len(validation_indices)}"
    )
# Out:
# Fold 1: Training = 29920, Validation = 7480
# Fold 2: Training = 29920, Validation = 7480
# Fold 3: Training = 29920, Validation = 7480
# Fold 4: Training = 29920, Validation = 7480
# Fold 5: Training = 29920, Validation = 7480

# %%
def build_xception(fold_seed):
    tf.keras.utils.set_random_seed(
        fold_seed
    )

    augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomRotation(0.05),
        tf.keras.layers.RandomZoom(0.10),
        tf.keras.layers.RandomTranslation(
            0.05,
            0.05
        )
    ])

    xception_base = tf.keras.applications.Xception(
        weights="imagenet",
        include_top=False,
        input_shape=(224, 224, 3)
    )

    xception_base.trainable = False

    inputs = tf.keras.Input(
        shape=(224, 224, 3)
    )

    x = augmentation(inputs)

    x = tf.keras.applications.xception.preprocess_input(
        x
    )

    x = xception_base(
        x,
        training=False
    )

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.30)(x)

    outputs = tf.keras.layers.Dense(
        1,
        activation="sigmoid"
    )(x)

    model = tf.keras.Model(
        inputs,
        outputs,
        name="Xception_Binary"
    )

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=LEARNING_RATE
        ),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
from sklearn.utils.class_weight import (
    compute_class_weight
)

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)

fold_histories = {}
fold_results = []
fold_test_probabilities = []

print("Cross-validation storage initialized.")
# Out:
# Cross-validation storage initialized.

# %%
for fold, (train_indices, validation_indices) in enumerate(
    cross_validator.split(
        development_df,
        development_df["label"]
    ),
    start=1
):
    print(f"\n{'=' * 20} FOLD {fold}/5 {'=' * 20}")

    fold_train_df = development_df.iloc[
        train_indices
    ].reset_index(drop=True)

    fold_validation_df = development_df.iloc[
        validation_indices
    ].reset_index(drop=True)

    train_dataset = create_dataset(
        fold_train_df,
        training=True,
        shuffle_seed=SEED + fold
    )

    validation_dataset = create_dataset(
        fold_validation_df
    )

    weights = compute_class_weight(
        class_weight="balanced",
        classes=np.array([0, 1]),
        y=fold_train_df["label"]
    )

    fold_class_weights = {
        0: float(weights[0]),
        1: float(weights[1])
    }

    tf.keras.backend.clear_session()
    gc.collect()

    model = build_xception(
        SEED + fold
    )

    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=PATIENCE,
            restore_best_weights=True,
            verbose=1
        ),

        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=2,
            min_lr=1e-7,
            verbose=1
        )
    ]

    start_time = time.time()

    history = model.fit(
        train_dataset,
        validation_data=validation_dataset,
        epochs=MAX_EPOCHS,
        class_weight=fold_class_weights,
        callbacks=callbacks,
        verbose=1
    )

    training_minutes = (
        time.time() - start_time
    ) / 60

    fold_history = pd.DataFrame(
        history.history
    )

    fold_histories[fold] = fold_history

    best_index = fold_history[
        "val_loss"
    ].idxmin()

    validation_probabilities = model.predict(
        validation_dataset,
        verbose=0
    ).ravel()

    validation_labels = fold_validation_df[
        "label"
    ].to_numpy()

    validation_predictions = (
        validation_probabilities >= 0.5
    ).astype(int)

    fold_results.append({
        "Fold": fold,
        "Epochs Trained": len(fold_history),
        "Best Epoch": best_index + 1,

        "Training Loss": fold_history.loc[
            best_index,
            "loss"
        ],

        "Training Accuracy": fold_history.loc[
            best_index,
            "accuracy"
        ],

        "Validation Loss": fold_history.loc[
            best_index,
            "val_loss"
        ],

        "Validation Accuracy": fold_history.loc[
            best_index,
            "val_accuracy"
        ],

        "Precision": precision_score(
            validation_labels,
            validation_predictions
        ),

        "Recall": recall_score(
            validation_labels,
            validation_predictions
        ),

        "F1-score": f1_score(
            validation_labels,
            validation_predictions
        ),

        "ROC-AUC": roc_auc_score(
            validation_labels,
            validation_probabilities
        ),

        "Training Minutes": training_minutes
    })

    fold_test_probabilities.append(
        model.predict(
            test_dataset,
            verbose=0
        ).ravel()
    )

    print(
        f"Fold {fold} completed in "
        f"{training_minutes:.2f} minutes"
    )

    del model
    gc.collect()
# Out:
# ==================== FOLD 1/5 ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 117s 117ms/step - accuracy: 0.6500 - loss: 0.6212 - val_accuracy: 0.6884 - val_loss: 0.5976 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7112 - loss: 0.5664 - val_accuracy: 0.7176 - val_loss: 0.5683 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7298 - loss: 0.5439 - val_accuracy: 0.7193 - val_loss: 0.5640 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7372 - loss: 0.5347 - val_accuracy: 0.6949 - val_loss: 0.5882 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7433 - loss: 0.5277
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7450 - loss: 0.5253 - val_accuracy: 0.7012 - val_loss: 0.5838 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7484 - loss: 0.5232 - val_accuracy: 0.7082 - val_loss: 0.5758 - learning_rate: 5.0000e-05
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7512 - loss: 0.5165 - val_accuracy: 0.7275 - val_loss: 0.5534 - learning_rate: 5.0000e-05
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7510 - loss: 0.5174 - val_accuracy: 0.7015 - val_loss: 0.5797 - learning_rate: 5.0000e-05
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7492 - loss: 0.5147
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7497 - loss: 0.5162 - val_accuracy: 0.7187 - val_loss: 0.5608 - learning_rate: 5.0000e-05
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 109s 116ms/step - accuracy: 0.7543 - loss: 0.5133 - val_accuracy: 0.7142 - val_loss: 0.5660 - learning_rate: 2.5000e-05
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7470 - loss: 0.5161
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7516 - loss: 0.5141 - val_accuracy: 0.7032 - val_loss: 0.5770 - learning_rate: 2.5000e-05
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7533 - loss: 0.5121 - val_accuracy: 0.7130 - val_loss: 0.5668 - learning_rate: 1.2500e-05
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Fold 1 completed in 21.72 minutes
#
# ==================== FOLD 2/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 114s 117ms/step - accuracy: 0.6615 - loss: 0.6116 - val_accuracy: 0.7146 - val_loss: 0.5762 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7156 - loss: 0.5602 - val_accuracy: 0.7075 - val_loss: 0.5746 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7356 - loss: 0.5423 - val_accuracy: 0.7074 - val_loss: 0.5707 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7428 - loss: 0.5322 - val_accuracy: 0.6991 - val_loss: 0.5783 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7475 - loss: 0.5218
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7472 - loss: 0.5254 - val_accuracy: 0.6848 - val_loss: 0.5973 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7474 - loss: 0.5192 - val_accuracy: 0.7114 - val_loss: 0.5631 - learning_rate: 5.0000e-05
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7486 - loss: 0.5195 - val_accuracy: 0.6979 - val_loss: 0.5822 - learning_rate: 5.0000e-05
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7490 - loss: 0.5204
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7524 - loss: 0.5162 - val_accuracy: 0.7078 - val_loss: 0.5660 - learning_rate: 5.0000e-05
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7542 - loss: 0.5148 - val_accuracy: 0.7066 - val_loss: 0.5687 - learning_rate: 2.5000e-05
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7531 - loss: 0.5150
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7532 - loss: 0.5122 - val_accuracy: 0.7070 - val_loss: 0.5679 - learning_rate: 2.5000e-05
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7528 - loss: 0.5162 - val_accuracy: 0.7074 - val_loss: 0.5671 - learning_rate: 1.2500e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Fold 2 completed in 19.79 minutes
#
# ==================== FOLD 3/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 113s 116ms/step - accuracy: 0.6252 - loss: 0.6378 - val_accuracy: 0.7289 - val_loss: 0.5661 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7122 - loss: 0.5685 - val_accuracy: 0.6849 - val_loss: 0.5911 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7233 - loss: 0.5559
# Epoch 3: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7286 - loss: 0.5483 - val_accuracy: 0.6913 - val_loss: 0.5879 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7398 - loss: 0.5384 - val_accuracy: 0.7056 - val_loss: 0.5739 - learning_rate: 5.0000e-05
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7371 - loss: 0.5383
# Epoch 5: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7396 - loss: 0.5345 - val_accuracy: 0.6980 - val_loss: 0.5810 - learning_rate: 5.0000e-05
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7452 - loss: 0.5279 - val_accuracy: 0.6961 - val_loss: 0.5819 - learning_rate: 2.5000e-05
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Fold 3 completed in 10.84 minutes
#
# ==================== FOLD 4/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 113s 117ms/step - accuracy: 0.6369 - loss: 0.6245 - val_accuracy: 0.6881 - val_loss: 0.5976 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7128 - loss: 0.5672 - val_accuracy: 0.6877 - val_loss: 0.5947 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7331 - loss: 0.5445 - val_accuracy: 0.7221 - val_loss: 0.5585 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7388 - loss: 0.5350 - val_accuracy: 0.7031 - val_loss: 0.5799 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7403 - loss: 0.5319
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7440 - loss: 0.5267 - val_accuracy: 0.7124 - val_loss: 0.5678 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7525 - loss: 0.5213 - val_accuracy: 0.6906 - val_loss: 0.5897 - learning_rate: 5.0000e-05
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7489 - loss: 0.5213
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7526 - loss: 0.5177 - val_accuracy: 0.6992 - val_loss: 0.5821 - learning_rate: 5.0000e-05
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7540 - loss: 0.5151 - val_accuracy: 0.7063 - val_loss: 0.5740 - learning_rate: 2.5000e-05
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Fold 4 completed in 14.43 minutes
#
# ==================== FOLD 5/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 113s 116ms/step - accuracy: 0.6447 - loss: 0.6228 - val_accuracy: 0.7108 - val_loss: 0.5826 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7146 - loss: 0.5658 - val_accuracy: 0.6912 - val_loss: 0.5983 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7299 - loss: 0.5492
# Epoch 3: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7327 - loss: 0.5463 - val_accuracy: 0.6848 - val_loss: 0.6012 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7380 - loss: 0.5360 - val_accuracy: 0.6580 - val_loss: 0.6249 - learning_rate: 5.0000e-05
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7396 - loss: 0.5306
# Epoch 5: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7402 - loss: 0.5324 - val_accuracy: 0.6771 - val_loss: 0.6086 - learning_rate: 5.0000e-05
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7433 - loss: 0.5316 - val_accuracy: 0.6939 - val_loss: 0.5919 - learning_rate: 2.5000e-05
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Fold 5 completed in 10.83 minutes

# %%
fold_results_df = pd.DataFrame(
    fold_results
)

display(
    fold_results_df.round(4)
)
# Out:
#    Fold  Epochs Trained  Best Epoch  Training Loss  Training Accuracy  \
# 0     1              12           7         0.5165             0.7512
# 1     2              11           6         0.5192             0.7474
# 2     3               6           1         0.6378             0.6252
# 3     4               8           3         0.5445             0.7331
# 4     5               6           1         0.6228             0.6447
#
#    Validation Loss  Validation Accuracy  Precision  Recall  F1-score  ROC-AUC  \
# 0           0.5534               0.7275     0.9010  0.6917    0.7826   0.8317
# 1           0.5631               0.7114     0.9004  0.6667    0.7661   0.8303
# 2           0.5661               0.7289     0.8459  0.7553    0.7980   0.7801
# 3           0.5585               0.7221     0.8848  0.6991    0.7810   0.8171
# 4           0.5826               0.7108     0.8603  0.7070    0.7762   0.7863
#
#    Training Minutes
# 0           21.7201
# 1           19.7924
# 2           10.8354
# 3           14.4295
# 4           10.8341

# %%
summary_columns = [
    "Training Loss",
    "Training Accuracy",
    "Validation Loss",
    "Validation Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "ROC-AUC"
]

cv_summary_df = pd.DataFrame({
    "Mean": fold_results_df[
        summary_columns
    ].mean(),

    "Standard Deviation": fold_results_df[
        summary_columns
    ].std()
})

display(
    cv_summary_df.round(4)
)
# Out:
#                        Mean  Standard Deviation
# Training Loss        0.5682              0.0580
# Training Accuracy    0.7003              0.0604
# Validation Loss      0.5647              0.0111
# Validation Accuracy  0.7201              0.0086
# Precision            0.8785              0.0246
# Recall               0.7040              0.0324
# F1-score             0.7808              0.0116
# ROC-AUC              0.8091              0.0244

# %%
test_probabilities_cv = np.mean(
    np.vstack(
        fold_test_probabilities
    ),
    axis=0
)

test_predictions_cv = (
    test_probabilities_cv >= 0.5
).astype(int)

true_test_labels = test_df[
    "label"
].to_numpy()

print("Test images:", len(true_test_labels))
print(
    "Ensemble predictions:",
    len(test_predictions_cv)
)
# Out:
# Test images: 6600
# Ensemble predictions: 6600

# %%
from sklearn.metrics import (
    log_loss,
    accuracy_score
)

test_loss_cv = log_loss(
    true_test_labels,
    test_probabilities_cv
)

test_accuracy_cv = accuracy_score(
    true_test_labels,
    test_predictions_cv
)

print(
    "Test Loss:",
    round(test_loss_cv, 4)
)

print(
    "Test Accuracy:",
    round(test_accuracy_cv, 4)
)
# Out:
# Test Loss: 0.5497
# Test Accuracy: 0.7317

# %%
test_precision_cv = precision_score(
    true_test_labels,
    test_predictions_cv
)

test_recall_cv = recall_score(
    true_test_labels,
    test_predictions_cv
)

test_f1_cv = f1_score(
    true_test_labels,
    test_predictions_cv
)

test_auc_cv = roc_auc_score(
    true_test_labels,
    test_probabilities_cv
)

print(
    "Precision:",
    round(test_precision_cv, 4)
)

print(
    "Recall:",
    round(test_recall_cv, 4)
)

print(
    "F1-score:",
    round(test_f1_cv, 4)
)

print(
    "ROC-AUC:",
    round(test_auc_cv, 4)
)
# Out:
# Precision: 0.8863
# Recall: 0.713
# F1-score: 0.7903
# ROC-AUC: 0.8286

# %%
from sklearn.metrics import confusion_matrix

cm_cv = confusion_matrix(
    true_test_labels,
    test_predictions_cv
)

plt.figure(figsize=(7, 5))

sns.heatmap(
    cm_cv,
    annot=True,
    fmt="d",
    cmap="Reds",
    xticklabels=[
        "NonDemented",
        "Demented"
    ],
    yticklabels=[
        "NonDemented",
        "Demented"
    ]
)

plt.title(
    "Xception 5-Fold CV Test Confusion Matrix"
)
plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.tight_layout()
plt.show()

# %%
mean_validation_accuracy = (
    fold_results_df[
        "Validation Accuracy"
    ].mean()
)

plt.figure(figsize=(8, 5))

bars = plt.bar(
    fold_results_df["Fold"],
    fold_results_df[
        "Validation Accuracy"
    ],
    color="indianred"
)

plt.axhline(
    mean_validation_accuracy,
    color="black",
    linestyle="--",
    label=(
        f"Mean = "
        f"{mean_validation_accuracy:.4f}"
    )
)

for bar, value in zip(
    bars,
    fold_results_df[
        "Validation Accuracy"
    ]
):
    plt.text(
        bar.get_x()
        + bar.get_width() / 2,
        value + 0.003,
        f"{value:.4f}",
        ha="center"
    )

plt.ylim(0, 1)
plt.title(
    "Xception Validation Accuracy Across Five Folds"
)
plt.xlabel("Fold")
plt.ylabel("Validation Accuracy")
plt.xticks(fold_results_df["Fold"])
plt.legend()
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

for fold, fold_history in fold_histories.items():
    epochs = range(
        1,
        len(fold_history) + 1
    )

    plt.plot(
        epochs,
        fold_history["loss"],
        label=f"Fold {fold} Training"
    )

    plt.plot(
        epochs,
        fold_history["val_loss"],
        linestyle="--",
        label=f"Fold {fold} Validation"
    )

plt.title(
    "Xception Training and Validation Loss Across Five Folds"
)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(ncol=2, fontsize=9)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

for fold, fold_history in fold_histories.items():
    epochs = range(
        1,
        len(fold_history) + 1
    )

    plt.plot(
        epochs,
        fold_history["accuracy"],
        label=f"Fold {fold} Training"
    )

    plt.plot(
        epochs,
        fold_history["val_accuracy"],
        linestyle="--",
        label=f"Fold {fold} Validation"
    )

plt.title(
    "Xception Training and Validation Accuracy Across Five Folds"
)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(ncol=2, fontsize=9)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve

fpr_cv, tpr_cv, _ = roc_curve(
    true_test_labels,
    test_probabilities_cv
)

plt.figure(figsize=(7, 5))

plt.plot(
    fpr_cv,
    tpr_cv,
    label=(
        f"Xception 5-Fold CV "
        f"(AUC = {test_auc_cv:.4f})"
    )
)

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--",
    color="gray",
    label="Random Classifier"
)

plt.title(
    "Xception 5-Fold CV Test ROC Curve"
)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
sample_indices = np.random.default_rng(
    SEED
).choice(
    len(test_df),
    size=12,
    replace=False
)

plt.figure(figsize=(16, 12))

for position, index in enumerate(
    sample_indices,
    start=1
):
    image = tf.keras.utils.load_img(
        test_df.iloc[index]["filepath"],
        target_size=IMG_SIZE
    )

    actual = true_test_labels[index]
    predicted = test_predictions_cv[index]
    probability = test_probabilities_cv[index]

    actual_name = (
        "Demented"
        if actual == 1
        else "NonDemented"
    )

    predicted_name = (
        "Demented"
        if predicted == 1
        else "NonDemented"
    )

    title_color = (
        "green"
        if actual == predicted
        else "red"
    )

    plt.subplot(3, 4, position)
    plt.imshow(image)

    plt.title(
        f"Actual: {actual_name}\n"
        f"Predicted: {predicted_name}\n"
        f"Probability: {probability:.3f}",
        color=title_color,
        fontsize=10
    )

    plt.axis("off")

plt.suptitle(
    "Xception 5-Fold CV Sanity Test",
    fontsize=16
)

plt.tight_layout()
plt.show()

# %%
test_results_df = pd.DataFrame({
    "Model": ["Xception"],
    "Cross-Validation": ["5-Fold"],
    "Test Loss": [test_loss_cv],
    "Accuracy": [test_accuracy_cv],
    "Precision": [test_precision_cv],
    "Recall": [test_recall_cv],
    "F1-score": [test_f1_cv],
    "ROC-AUC": [test_auc_cv]
})

all_histories_df = pd.concat(
    [
        history.assign(
            Fold=fold,
            Epoch=range(
                1,
                len(history) + 1
            )
        )
        for fold, history
        in fold_histories.items()
    ],
    ignore_index=True
)

fold_results_df.to_csv(
    "/kaggle/working/xception_cv_fold_results.csv",
    index=False
)

cv_summary_df.to_csv(
    "/kaggle/working/xception_cv_summary.csv"
)

test_results_df.to_csv(
    "/kaggle/working/xception_cv_test_results.csv",
    index=False
)

all_histories_df.to_csv(
    "/kaggle/working/xception_cv_training_history.csv",
    index=False
)

display(
    test_results_df.round(4)
)

print(
    "All Xception CV result files saved."
)
# Out:
#       Model Cross-Validation  Test Loss  Accuracy  Precision  Recall  \
# 0  Xception           5-Fold     0.5497    0.7317     0.8863   0.713
#
#    F1-score  ROC-AUC
# 0    0.7903   0.8286
# All Xception CV result files saved.
