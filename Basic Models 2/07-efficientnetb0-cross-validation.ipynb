# %%
import os
import gc
import time
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import kagglehub

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow version:", tf.__version__)
print("Available GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow version: 2.20.0
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
dataset_path = Path(
    kagglehub.dataset_download(
        "aryansinghal10/alzheimers-multiclass-dataset-equal-and-augmented"
    )
)

image_root = dataset_path / "combined_images"

print("Dataset path:", dataset_path)
print("Image folder exists:", image_root.exists())
# Out:
# Dataset path: /kaggle/input/datasets/aryansinghal10/alzheimers-multiclass-dataset-equal-and-augmented
# Image folder exists: True

# %%
class_to_binary = {
    "NonDemented": 0,
    "VeryMildDemented": 1,
    "MildDemented": 1,
    "ModerateDemented": 1
}

records = []

for class_name, binary_label in class_to_binary.items():
    class_folder = image_root / class_name

    for image_path in sorted(class_folder.iterdir()):
        if image_path.suffix.lower() in {
            ".jpg", ".jpeg", ".png"
        }:
            records.append({
                "filepath": str(image_path),
                "original_class": class_name,
                "label": binary_label
            })

df = pd.DataFrame(records)

print("Total images:", len(df))
print(df["label"].value_counts().sort_index())
# Out:
# Total images: 44000
# label
# 0    12800
# 1    31200
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

development_df, test_df = train_test_split(
    df,
    test_size=0.15,
    stratify=df["label"],
    random_state=SEED
)

development_df = development_df.reset_index(
    drop=True
)

test_df = test_df.reset_index(
    drop=True
)

print("Development images:", len(development_df))
print(development_df["label"].value_counts().sort_index())

print("\nTest images:", len(test_df))
print(test_df["label"].value_counts().sort_index())
# Out:
# Development images: 37400
# label
# 0    10880
# 1    26520
# Name: count, dtype: int64
#
# Test images: 6600
# label
# 0    1920
# 1    4680
# Name: count, dtype: int64

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

def load_and_resize_image(filepath, label):
    image = tf.io.read_file(filepath)

    image = tf.io.decode_image(
        image,
        channels=3,
        expand_animations=False
    )

    image.set_shape([None, None, 3])
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.cast(image, tf.float32)
    label = tf.cast(label, tf.float32)

    return image, label


def create_dataset(
    dataframe,
    training=False,
    shuffle_seed=SEED
):
    dataset = tf.data.Dataset.from_tensor_slices(
        (
            dataframe["filepath"].values,
            dataframe["label"].values
        )
    )

    if training:
        dataset = dataset.shuffle(
            buffer_size=min(
                len(dataframe),
                10000
            ),
            seed=shuffle_seed,
            reshuffle_each_iteration=True
        )

    dataset = dataset.map(
        load_and_resize_image,
        num_parallel_calls=AUTOTUNE
    )

    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE)

    return dataset


test_dataset = create_dataset(test_df)

for images, labels in test_dataset.take(1):
    print("Image batch shape:", images.shape)
    print("Label batch shape:", labels.shape)
    print(
        "Pixel range:",
        float(tf.reduce_min(images)),
        "to",
        float(tf.reduce_max(images))
    )
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787577593.228352      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Image batch shape: (32, 224, 224, 3)
# Label batch shape: (32,)
# Pixel range: 0.0 to 255.0

# %%
from sklearn.model_selection import StratifiedKFold

MAX_EPOCHS = 30
PATIENCE = 5
LEARNING_RATE = 0.0001
N_FOLDS = 5

cross_validator = StratifiedKFold(
    n_splits=N_FOLDS,
    shuffle=True,
    random_state=SEED
)

for fold, (train_indices, validation_indices) in enumerate(
    cross_validator.split(
        development_df,
        development_df["label"]
    ),
    start=1
):
    print(
        f"Fold {fold}: "
        f"Training = {len(train_indices)}, "
        f"Validation = {len(validation_indices)}"
    )
# Out:
# Fold 1: Training = 29920, Validation = 7480
# Fold 2: Training = 29920, Validation = 7480
# Fold 3: Training = 29920, Validation = 7480
# Fold 4: Training = 29920, Validation = 7480
# Fold 5: Training = 29920, Validation = 7480

# %%
def build_efficientnetb0(fold_seed):
    tf.keras.utils.set_random_seed(
        fold_seed
    )

    augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomRotation(0.05),
        tf.keras.layers.RandomZoom(0.10),
        tf.keras.layers.RandomTranslation(
            0.05,
            0.05
        )
    ])

    efficientnet_base = (
        tf.keras.applications.EfficientNetB0(
            weights="imagenet",
            include_top=False,
            input_shape=(224, 224, 3)
        )
    )

    efficientnet_base.trainable = False

    inputs = tf.keras.Input(
        shape=(224, 224, 3)
    )

    x = augmentation(inputs)

    x = (
        tf.keras.applications.efficientnet
        .preprocess_input(x)
    )

    x = efficientnet_base(
        x,
        training=False
    )

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.30)(x)

    outputs = tf.keras.layers.Dense(
        1,
        activation="sigmoid"
    )(x)

    model = tf.keras.Model(
        inputs,
        outputs,
        name="EfficientNetB0_Binary"
    )

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=LEARNING_RATE
        ),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
from sklearn.utils.class_weight import (
    compute_class_weight
)

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)

fold_histories = {}
fold_results = []
fold_test_probabilities = []

print("Cross-validation storage initialized.")
# Out:
# Cross-validation storage initialized.

# %%
for fold, (train_indices, validation_indices) in enumerate(
    cross_validator.split(
        development_df,
        development_df["label"]
    ),
    start=1
):
    print(f"\n{'=' * 20} FOLD {fold}/5 {'=' * 20}")

    fold_train_df = development_df.iloc[
        train_indices
    ].reset_index(drop=True)

    fold_validation_df = development_df.iloc[
        validation_indices
    ].reset_index(drop=True)

    train_dataset = create_dataset(
        fold_train_df,
        training=True,
        shuffle_seed=SEED + fold
    )

    validation_dataset = create_dataset(
        fold_validation_df
    )

    weights = compute_class_weight(
        class_weight="balanced",
        classes=np.array([0, 1]),
        y=fold_train_df["label"]
    )

    fold_class_weights = {
        0: float(weights[0]),
        1: float(weights[1])
    }

    tf.keras.backend.clear_session()
    gc.collect()

    model = build_efficientnetb0(
        SEED + fold
    )

    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=PATIENCE,
            restore_best_weights=True,
            verbose=1
        ),

        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=2,
            min_lr=1e-7,
            verbose=1
        )
    ]

    start_time = time.time()

    history = model.fit(
        train_dataset,
        validation_data=validation_dataset,
        epochs=MAX_EPOCHS,
        class_weight=fold_class_weights,
        callbacks=callbacks,
        verbose=1
    )

    training_minutes = (
        time.time() - start_time
    ) / 60

    fold_history = pd.DataFrame(
        history.history
    )

    fold_histories[fold] = fold_history

    best_index = fold_history[
        "val_loss"
    ].idxmin()

    validation_probabilities = model.predict(
        validation_dataset,
        verbose=0
    ).ravel()

    validation_labels = fold_validation_df[
        "label"
    ].to_numpy()

    validation_predictions = (
        validation_probabilities >= 0.5
    ).astype(int)

    fold_results.append({
        "Fold": fold,
        "Epochs Trained": len(fold_history),
        "Best Epoch": best_index + 1,

        "Training Loss": fold_history.loc[
            best_index,
            "loss"
        ],

        "Training Accuracy": fold_history.loc[
            best_index,
            "accuracy"
        ],

        "Validation Loss": fold_history.loc[
            best_index,
            "val_loss"
        ],

        "Validation Accuracy": fold_history.loc[
            best_index,
            "val_accuracy"
        ],

        "Precision": precision_score(
            validation_labels,
            validation_predictions
        ),

        "Recall": recall_score(
            validation_labels,
            validation_predictions
        ),

        "F1-score": f1_score(
            validation_labels,
            validation_predictions
        ),

        "ROC-AUC": roc_auc_score(
            validation_labels,
            validation_probabilities
        ),

        "Training Minutes": training_minutes
    })

    fold_test_probabilities.append(
        model.predict(
            test_dataset,
            verbose=0
        ).ravel()
    )

    print(
        f"Fold {fold} completed in "
        f"{training_minutes:.2f} minutes"
    )

    del model
    gc.collect()
# Out:
# ==================== FOLD 1/5 ====================
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/30
# E0000 00:00:1787577711.629698      58 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/EfficientNetB0_Binary_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 98s 91ms/step - accuracy: 0.5717 - loss: 0.6776 - val_accuracy: 0.6747 - val_loss: 0.6205 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 58s 62ms/step - accuracy: 0.6480 - loss: 0.6258 - val_accuracy: 0.7278 - val_loss: 0.5749 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.6832 - loss: 0.5985 - val_accuracy: 0.7412 - val_loss: 0.5571 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.6987 - loss: 0.5814 - val_accuracy: 0.7269 - val_loss: 0.5649 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7097 - loss: 0.5705 - val_accuracy: 0.7374 - val_loss: 0.5545 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7205 - loss: 0.5605 - val_accuracy: 0.7282 - val_loss: 0.5602 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 59s 63ms/step - accuracy: 0.7250 - loss: 0.5545 - val_accuracy: 0.7480 - val_loss: 0.5380 - learning_rate: 1.0000e-04
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7290 - loss: 0.5485 - val_accuracy: 0.7158 - val_loss: 0.5723 - learning_rate: 1.0000e-04
# Epoch 9/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7263 - loss: 0.5486
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7281 - loss: 0.5474 - val_accuracy: 0.7420 - val_loss: 0.5439 - learning_rate: 1.0000e-04
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7351 - loss: 0.5428 - val_accuracy: 0.7246 - val_loss: 0.5623 - learning_rate: 5.0000e-05
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7354 - loss: 0.5425
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7355 - loss: 0.5420 - val_accuracy: 0.7191 - val_loss: 0.5682 - learning_rate: 5.0000e-05
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7320 - loss: 0.5410 - val_accuracy: 0.7294 - val_loss: 0.5566 - learning_rate: 2.5000e-05
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Fold 1 completed in 12.16 minutes
#
# ==================== FOLD 2/5 ====================
# Epoch 1/30
# E0000 00:00:1787578472.471210      58 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/EfficientNetB0_Binary_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 70s 64ms/step - accuracy: 0.5805 - loss: 0.6762 - val_accuracy: 0.6999 - val_loss: 0.6088 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.6520 - loss: 0.6236 - val_accuracy: 0.7167 - val_loss: 0.5857 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.6845 - loss: 0.5958 - val_accuracy: 0.7199 - val_loss: 0.5801 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.6958 - loss: 0.5834 - val_accuracy: 0.7126 - val_loss: 0.5835 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7097 - loss: 0.5713 - val_accuracy: 0.7115 - val_loss: 0.5794 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7188 - loss: 0.5628 - val_accuracy: 0.7317 - val_loss: 0.5582 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7232 - loss: 0.5555 - val_accuracy: 0.6979 - val_loss: 0.5942 - learning_rate: 1.0000e-04
# Epoch 8/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7225 - loss: 0.5498
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7271 - loss: 0.5480 - val_accuracy: 0.7193 - val_loss: 0.5666 - learning_rate: 1.0000e-04
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 58s 62ms/step - accuracy: 0.7351 - loss: 0.5448 - val_accuracy: 0.7122 - val_loss: 0.5752 - learning_rate: 5.0000e-05
# Epoch 10/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7309 - loss: 0.5470
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 59s 63ms/step - accuracy: 0.7326 - loss: 0.5434 - val_accuracy: 0.7179 - val_loss: 0.5667 - learning_rate: 5.0000e-05
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7300 - loss: 0.5430 - val_accuracy: 0.7124 - val_loss: 0.5740 - learning_rate: 2.5000e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Fold 2 completed in 10.74 minutes
#
# ==================== FOLD 3/5 ====================
# Epoch 1/30
# E0000 00:00:1787579145.693121      58 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/EfficientNetB0_Binary_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 71s 64ms/step - accuracy: 0.5724 - loss: 0.6865 - val_accuracy: 0.7306 - val_loss: 0.5822 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.6517 - loss: 0.6242 - val_accuracy: 0.7099 - val_loss: 0.5868 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 58s 62ms/step - accuracy: 0.6842 - loss: 0.5989 - val_accuracy: 0.7356 - val_loss: 0.5607 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7060 - loss: 0.5792 - val_accuracy: 0.7396 - val_loss: 0.5500 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7135 - loss: 0.5713 - val_accuracy: 0.7369 - val_loss: 0.5558 - learning_rate: 1.0000e-04
# Epoch 6/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7194 - loss: 0.5644
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 58s 62ms/step - accuracy: 0.7199 - loss: 0.5626 - val_accuracy: 0.7332 - val_loss: 0.5546 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7246 - loss: 0.5560 - val_accuracy: 0.7316 - val_loss: 0.5549 - learning_rate: 5.0000e-05
# Epoch 8/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7229 - loss: 0.5569
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7258 - loss: 0.5541 - val_accuracy: 0.7333 - val_loss: 0.5529 - learning_rate: 5.0000e-05
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 61s 65ms/step - accuracy: 0.7267 - loss: 0.5533 - val_accuracy: 0.7386 - val_loss: 0.5463 - learning_rate: 2.5000e-05
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 60s 64ms/step - accuracy: 0.7293 - loss: 0.5507 - val_accuracy: 0.7402 - val_loss: 0.5443 - learning_rate: 2.5000e-05
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 58s 61ms/step - accuracy: 0.7333 - loss: 0.5465 - val_accuracy: 0.7426 - val_loss: 0.5416 - learning_rate: 2.5000e-05
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7282 - loss: 0.5473 - val_accuracy: 0.7487 - val_loss: 0.5345 - learning_rate: 2.5000e-05
# Epoch 13/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7295 - loss: 0.5469 - val_accuracy: 0.7433 - val_loss: 0.5398 - learning_rate: 2.5000e-05
# Epoch 14/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7336 - loss: 0.5451
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 56s 60ms/step - accuracy: 0.7328 - loss: 0.5459 - val_accuracy: 0.7330 - val_loss: 0.5495 - learning_rate: 2.5000e-05
# Epoch 15/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 58s 61ms/step - accuracy: 0.7334 - loss: 0.5452 - val_accuracy: 0.7285 - val_loss: 0.5528 - learning_rate: 1.2500e-05
# Epoch 16/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7262 - loss: 0.5530
# Epoch 16: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7324 - loss: 0.5454 - val_accuracy: 0.7370 - val_loss: 0.5450 - learning_rate: 1.2500e-05
# Epoch 17/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 59s 63ms/step - accuracy: 0.7351 - loss: 0.5450 - val_accuracy: 0.7309 - val_loss: 0.5506 - learning_rate: 6.2500e-06
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Fold 3 completed in 16.56 minutes
#
# ==================== FOLD 4/5 ====================
# Epoch 1/30
# E0000 00:00:1787580167.047791      58 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/EfficientNetB0_Binary_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.5937 - loss: 0.6644 - val_accuracy: 0.6477 - val_loss: 0.6320 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 63s 68ms/step - accuracy: 0.6605 - loss: 0.6172 - val_accuracy: 0.6719 - val_loss: 0.6118 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.6843 - loss: 0.5948 - val_accuracy: 0.7184 - val_loss: 0.5758 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7063 - loss: 0.5806 - val_accuracy: 0.7019 - val_loss: 0.5842 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7125 - loss: 0.5686 - val_accuracy: 0.7191 - val_loss: 0.5692 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7176 - loss: 0.5642 - val_accuracy: 0.7004 - val_loss: 0.5828 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7209 - loss: 0.5607
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7253 - loss: 0.5564 - val_accuracy: 0.6916 - val_loss: 0.5900 - learning_rate: 1.0000e-04
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7300 - loss: 0.5505 - val_accuracy: 0.7146 - val_loss: 0.5694 - learning_rate: 5.0000e-05
# Epoch 9/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7307 - loss: 0.5501
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7280 - loss: 0.5499 - val_accuracy: 0.6916 - val_loss: 0.5890 - learning_rate: 5.0000e-05
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7308 - loss: 0.5468 - val_accuracy: 0.7083 - val_loss: 0.5749 - learning_rate: 2.5000e-05
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Fold 4 completed in 9.80 minutes
#
# ==================== FOLD 5/5 ====================
# Epoch 1/30
# E0000 00:00:1787580782.502055      58 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/EfficientNetB0_Binary_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.5951 - loss: 0.6684 - val_accuracy: 0.7048 - val_loss: 0.6064 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.6643 - loss: 0.6181 - val_accuracy: 0.6825 - val_loss: 0.6116 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.6911 - loss: 0.5954 - val_accuracy: 0.6921 - val_loss: 0.6013 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 58s 61ms/step - accuracy: 0.7022 - loss: 0.5820 - val_accuracy: 0.6881 - val_loss: 0.5995 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 60ms/step - accuracy: 0.7098 - loss: 0.5701 - val_accuracy: 0.6916 - val_loss: 0.5946 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7193 - loss: 0.5629 - val_accuracy: 0.6945 - val_loss: 0.5929 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7252 - loss: 0.5541 - val_accuracy: 0.6959 - val_loss: 0.5926 - learning_rate: 1.0000e-04
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7249 - loss: 0.5527 - val_accuracy: 0.7167 - val_loss: 0.5674 - learning_rate: 1.0000e-04
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7288 - loss: 0.5464 - val_accuracy: 0.7237 - val_loss: 0.5606 - learning_rate: 1.0000e-04
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7370 - loss: 0.5419 - val_accuracy: 0.7098 - val_loss: 0.5741 - learning_rate: 1.0000e-04
# Epoch 11/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7327 - loss: 0.5414
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7373 - loss: 0.5375 - val_accuracy: 0.7131 - val_loss: 0.5705 - learning_rate: 1.0000e-04
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7392 - loss: 0.5319 - val_accuracy: 0.7191 - val_loss: 0.5629 - learning_rate: 5.0000e-05
# Epoch 13/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7374 - loss: 0.5314
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7353 - loss: 0.5357 - val_accuracy: 0.7075 - val_loss: 0.5784 - learning_rate: 5.0000e-05
# Epoch 14/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 57s 61ms/step - accuracy: 0.7359 - loss: 0.5342 - val_accuracy: 0.7112 - val_loss: 0.5724 - learning_rate: 2.5000e-05
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Fold 5 completed in 13.51 minutes

# %%
fold_results_df = pd.DataFrame(
    fold_results
)

display(
    fold_results_df.round(4)
)
# Out:
#    Fold  Epochs Trained  Best Epoch  Training Loss  Training Accuracy  \
# 0     1              12           7         0.5545             0.7250
# 1     2              11           6         0.5628             0.7188
# 2     3              17          12         0.5473             0.7282
# 3     4              10           5         0.5686             0.7125
# 4     5              14           9         0.5464             0.7288
#
#    Validation Loss  Validation Accuracy  Precision  Recall  F1-score  ROC-AUC  \
# 0           0.5380               0.7480     0.8934  0.7319    0.8046   0.8307
# 1           0.5582               0.7317     0.8905  0.7087    0.7893   0.8220
# 2           0.5345               0.7487     0.8934  0.7330    0.8053   0.8331
# 3           0.5692               0.7191     0.8959  0.6833    0.7753   0.8217
# 4           0.5606               0.7237     0.9051  0.6817    0.7777   0.8320
#
#    Training Minutes
# 0           12.1641
# 1           10.7381
# 2           16.5632
# 3            9.8007
# 4           13.5147

# %%
summary_columns = [
    "Training Loss",
    "Training Accuracy",
    "Validation Loss",
    "Validation Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "ROC-AUC"
]

cv_summary_df = pd.DataFrame({
    "Mean": fold_results_df[
        summary_columns
    ].mean(),

    "Standard Deviation": fold_results_df[
        summary_columns
    ].std()
})

display(
    cv_summary_df.round(4)
)
# Out:
#                        Mean  Standard Deviation
# Training Loss        0.5560              0.0097
# Training Accuracy    0.7227              0.0069
# Validation Loss      0.5521              0.0151
# Validation Accuracy  0.7342              0.0136
# Precision            0.8957              0.0056
# Recall               0.7077              0.0250
# F1-score             0.7904              0.0143
# ROC-AUC              0.8279              0.0056

# %%
test_probabilities_cv = np.mean(
    np.vstack(
        fold_test_probabilities
    ),
    axis=0
)

test_predictions_cv = (
    test_probabilities_cv >= 0.5
).astype(int)

true_test_labels = test_df[
    "label"
].to_numpy()

print("Test images:", len(true_test_labels))
print(
    "Ensemble predictions:",
    len(test_predictions_cv)
)
# Out:
# Test images: 6600
# Ensemble predictions: 6600

# %%
from sklearn.metrics import (
    log_loss,
    accuracy_score
)

test_loss_cv = log_loss(
    true_test_labels,
    test_probabilities_cv
)

test_accuracy_cv = accuracy_score(
    true_test_labels,
    test_predictions_cv
)

print(
    "Test Loss:",
    round(test_loss_cv, 4)
)

print(
    "Test Accuracy:",
    round(test_accuracy_cv, 4)
)
# Out:
# Test Loss: 0.5477
# Test Accuracy: 0.7395

# %%
test_precision_cv = precision_score(
    true_test_labels,
    test_predictions_cv
)

test_recall_cv = recall_score(
    true_test_labels,
    test_predictions_cv
)

test_f1_cv = f1_score(
    true_test_labels,
    test_predictions_cv
)

test_auc_cv = roc_auc_score(
    true_test_labels,
    test_probabilities_cv
)

print(
    "Precision:",
    round(test_precision_cv, 4)
)

print(
    "Recall:",
    round(test_recall_cv, 4)
)

print(
    "F1-score:",
    round(test_f1_cv, 4)
)

print(
    "ROC-AUC:",
    round(test_auc_cv, 4)
)
# Out:
# Precision: 0.8945
# Recall: 0.7173
# F1-score: 0.7962
# ROC-AUC: 0.8316

# %%
from sklearn.metrics import confusion_matrix

cm_cv = confusion_matrix(
    true_test_labels,
    test_predictions_cv
)

plt.figure(figsize=(7, 5))

sns.heatmap(
    cm_cv,
    annot=True,
    fmt="d",
    cmap="Purples",
    xticklabels=[
        "NonDemented",
        "Demented"
    ],
    yticklabels=[
        "NonDemented",
        "Demented"
    ]
)

plt.title(
    "EfficientNetB0 5-Fold CV Test Confusion Matrix"
)
plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.tight_layout()
plt.show()

# %%
mean_validation_accuracy = (
    fold_results_df[
        "Validation Accuracy"
    ].mean()
)

plt.figure(figsize=(8, 5))

bars = plt.bar(
    fold_results_df["Fold"],
    fold_results_df[
        "Validation Accuracy"
    ],
    color="mediumpurple"
)

plt.axhline(
    mean_validation_accuracy,
    color="red",
    linestyle="--",
    label=(
        f"Mean = "
        f"{mean_validation_accuracy:.4f}"
    )
)

for bar, value in zip(
    bars,
    fold_results_df[
        "Validation Accuracy"
    ]
):
    plt.text(
        bar.get_x()
        + bar.get_width() / 2,
        value + 0.003,
        f"{value:.4f}",
        ha="center"
    )

plt.ylim(0, 1)
plt.title(
    "EfficientNetB0 Validation Accuracy Across Five Folds"
)
plt.xlabel("Fold")
plt.ylabel("Validation Accuracy")
plt.xticks(fold_results_df["Fold"])
plt.legend()
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# %%
test_precision_cv = precision_score(
    true_test_labels,
    test_predictions_cv
)

test_recall_cv = recall_score(
    true_test_labels,
    test_predictions_cv
)

test_f1_cv = f1_score(
    true_test_labels,
    test_predictions_cv
)

test_auc_cv = roc_auc_score(
    true_test_labels,
    test_probabilities_cv
)

print(
    "Precision:",
    round(test_precision_cv, 4)
)

print(
    "Recall:",
    round(test_recall_cv, 4)
)

print(
    "F1-score:",
    round(test_f1_cv, 4)
)

print(
    "ROC-AUC:",
    round(test_auc_cv, 4)
)
# Out:
# Precision: 0.8945
# Recall: 0.7173
# F1-score: 0.7962
# ROC-AUC: 0.8316

# %%
plt.figure(figsize=(10, 6))

for fold, fold_history in fold_histories.items():
    epochs = range(
        1,
        len(fold_history) + 1
    )

    plt.plot(
        epochs,
        fold_history["loss"],
        label=f"Fold {fold} Training"
    )

    plt.plot(
        epochs,
        fold_history["val_loss"],
        linestyle="--",
        label=f"Fold {fold} Validation"
    )

plt.title(
    "EfficientNetB0 Training and Validation Loss Across Five Folds"
)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(ncol=2, fontsize=9)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

for fold, fold_history in fold_histories.items():
    epochs = range(
        1,
        len(fold_history) + 1
    )

    plt.plot(
        epochs,
        fold_history["accuracy"],
        label=f"Fold {fold} Training"
    )

    plt.plot(
        epochs,
        fold_history["val_accuracy"],
        linestyle="--",
        label=f"Fold {fold} Validation"
    )

plt.title(
    "EfficientNetB0 Training and Validation Accuracy Across Five Folds"
)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(ncol=2, fontsize=9)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve

fpr_cv, tpr_cv, _ = roc_curve(
    true_test_labels,
    test_probabilities_cv
)

plt.figure(figsize=(7, 5))

plt.plot(
    fpr_cv,
    tpr_cv,
    label=(
        f"EfficientNetB0 5-Fold CV "
        f"(AUC = {test_auc_cv:.4f})"
    )
)

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--",
    color="gray",
    label="Random Classifier"
)

plt.title(
    "EfficientNetB0 5-Fold CV Test ROC Curve"
)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
sample_indices = np.random.default_rng(
    SEED
).choice(
    len(test_df),
    size=12,
    replace=False
)

plt.figure(figsize=(16, 12))

for position, index in enumerate(
    sample_indices,
    start=1
):
    image = tf.keras.utils.load_img(
        test_df.iloc[index]["filepath"],
        target_size=IMG_SIZE
    )

    actual = true_test_labels[index]
    predicted = test_predictions_cv[index]
    probability = test_probabilities_cv[index]

    actual_name = (
        "Demented"
        if actual == 1
        else "NonDemented"
    )

    predicted_name = (
        "Demented"
        if predicted == 1
        else "NonDemented"
    )

    title_color = (
        "green"
        if actual == predicted
        else "red"
    )

    plt.subplot(3, 4, position)
    plt.imshow(image)

    plt.title(
        f"Actual: {actual_name}\n"
        f"Predicted: {predicted_name}\n"
        f"Probability: {probability:.3f}",
        color=title_color,
        fontsize=10
    )

    plt.axis("off")

plt.suptitle(
    "EfficientNetB0 5-Fold CV Sanity Test",
    fontsize=16
)

plt.tight_layout()
plt.show()

# %%
test_results_df = pd.DataFrame({
    "Model": ["EfficientNetB0"],
    "Cross-Validation": ["5-Fold"],
    "Test Loss": [test_loss_cv],
    "Accuracy": [test_accuracy_cv],
    "Precision": [test_precision_cv],
    "Recall": [test_recall_cv],
    "F1-score": [test_f1_cv],
    "ROC-AUC": [test_auc_cv]
})

all_histories_df = pd.concat(
    [
        history.assign(
            Fold=fold,
            Epoch=range(
                1,
                len(history) + 1
            )
        )
        for fold, history
        in fold_histories.items()
    ],
    ignore_index=True
)

fold_results_df.to_csv(
    "/kaggle/working/efficientnetb0_cv_fold_results.csv",
    index=False
)

cv_summary_df.to_csv(
    "/kaggle/working/efficientnetb0_cv_summary.csv"
)

test_results_df.to_csv(
    "/kaggle/working/efficientnetb0_cv_test_results.csv",
    index=False
)

all_histories_df.to_csv(
    "/kaggle/working/efficientnetb0_cv_training_history.csv",
    index=False
)

display(
    test_results_df.round(4)
)

print(
    "All EfficientNetB0 CV result files saved."
)
# Out:
#             Model Cross-Validation  Test Loss  Accuracy  Precision  Recall  \
# 0  EfficientNetB0           5-Fold     0.5477    0.7395     0.8945  0.7173
#
#    F1-score  ROC-AUC
# 0    0.7962   0.8316
# All EfficientNetB0 CV result files saved.
