# %%
import os
import gc
import time
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import kagglehub

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow version:", tf.__version__)
print("Available GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow version: 2.20.0
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
dataset_path = Path(
    kagglehub.dataset_download(
        "aryansinghal10/alzheimers-multiclass-dataset-equal-and-augmented"
    )
)

image_root = dataset_path / "combined_images"

print("Dataset path:", dataset_path)
print("Image folder exists:", image_root.exists())
# Out:
# Dataset path: /kaggle/input/datasets/aryansinghal10/alzheimers-multiclass-dataset-equal-and-augmented
# Image folder exists: True

# %%
class_to_binary = {
    "NonDemented": 0,
    "VeryMildDemented": 1,
    "MildDemented": 1,
    "ModerateDemented": 1
}

records = []

for class_name, binary_label in class_to_binary.items():
    class_folder = image_root / class_name

    for image_path in sorted(class_folder.iterdir()):
        if image_path.suffix.lower() in {
            ".jpg", ".jpeg", ".png"
        }:
            records.append({
                "filepath": str(image_path),
                "original_class": class_name,
                "label": binary_label
            })

df = pd.DataFrame(records)

print("Total images:", len(df))
print(df["label"].value_counts().sort_index())
# Out:
# Total images: 44000
# label
# 0    12800
# 1    31200
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

development_df, test_df = train_test_split(
    df,
    test_size=0.15,
    stratify=df["label"],
    random_state=SEED
)

development_df = development_df.reset_index(
    drop=True
)

test_df = test_df.reset_index(
    drop=True
)

print("Development images:", len(development_df))
print(development_df["label"].value_counts().sort_index())

print("\nTest images:", len(test_df))
print(test_df["label"].value_counts().sort_index())
# Out:
# Development images: 37400
# label
# 0    10880
# 1    26520
# Name: count, dtype: int64
#
# Test images: 6600
# label
# 0    1920
# 1    4680
# Name: count, dtype: int64

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

def load_and_resize_image(filepath, label):
    image = tf.io.read_file(filepath)

    image = tf.io.decode_image(
        image,
        channels=3,
        expand_animations=False
    )

    image.set_shape([None, None, 3])
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.cast(image, tf.float32)
    label = tf.cast(label, tf.float32)

    return image, label


def create_dataset(
    dataframe,
    training=False,
    shuffle_seed=SEED
):
    dataset = tf.data.Dataset.from_tensor_slices(
        (
            dataframe["filepath"].values,
            dataframe["label"].values
        )
    )

    if training:
        dataset = dataset.shuffle(
            buffer_size=min(
                len(dataframe),
                10000
            ),
            seed=shuffle_seed,
            reshuffle_each_iteration=True
        )

    dataset = dataset.map(
        load_and_resize_image,
        num_parallel_calls=AUTOTUNE
    )

    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE)

    return dataset


test_dataset = create_dataset(test_df)

for images, labels in test_dataset.take(1):
    print("Image batch shape:", images.shape)
    print("Label batch shape:", labels.shape)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787568681.557772      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Image batch shape: (32, 224, 224, 3)
# Label batch shape: (32,)

# %%
from sklearn.model_selection import StratifiedKFold

MAX_EPOCHS = 30
PATIENCE = 5
LEARNING_RATE = 0.0001
N_FOLDS = 5

cross_validator = StratifiedKFold(
    n_splits=N_FOLDS,
    shuffle=True,
    random_state=SEED
)

for fold, (train_indices, validation_indices) in enumerate(
    cross_validator.split(
        development_df,
        development_df["label"]
    ),
    start=1
):
    print(
        f"Fold {fold}: "
        f"Training = {len(train_indices)}, "
        f"Validation = {len(validation_indices)}"
    )
# Out:
# Fold 1: Training = 29920, Validation = 7480
# Fold 2: Training = 29920, Validation = 7480
# Fold 3: Training = 29920, Validation = 7480
# Fold 4: Training = 29920, Validation = 7480
# Fold 5: Training = 29920, Validation = 7480

# %%
def build_densenet121(fold_seed):
    tf.keras.utils.set_random_seed(
        fold_seed
    )

    augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomRotation(0.05),
        tf.keras.layers.RandomZoom(0.10),
        tf.keras.layers.RandomTranslation(
            0.05,
            0.05
        )
    ])

    densenet_base = (
        tf.keras.applications.DenseNet121(
            weights="imagenet",
            include_top=False,
            input_shape=(224, 224, 3)
        )
    )

    densenet_base.trainable = False

    inputs = tf.keras.Input(
        shape=(224, 224, 3)
    )

    x = augmentation(inputs)

    x = (
        tf.keras.applications.densenet
        .preprocess_input(x)
    )

    x = densenet_base(
        x,
        training=False
    )

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.30)(x)

    outputs = tf.keras.layers.Dense(
        1,
        activation="sigmoid"
    )(x)

    model = tf.keras.Model(
        inputs,
        outputs,
        name="DenseNet121_Binary"
    )

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=LEARNING_RATE
        ),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
from sklearn.utils.class_weight import (
    compute_class_weight
)

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)

fold_histories = {}
fold_results = []
fold_test_probabilities = []

print("Cross-validation storage initialized.")
# Out:
# Cross-validation storage initialized.

# %%
for fold, (train_indices, validation_indices) in enumerate(
    cross_validator.split(
        development_df,
        development_df["label"]
    ),
    start=1
):
    print(f"\n{'=' * 20} FOLD {fold}/5 {'=' * 20}")

    fold_train_df = development_df.iloc[
        train_indices
    ].reset_index(drop=True)

    fold_validation_df = development_df.iloc[
        validation_indices
    ].reset_index(drop=True)

    train_dataset = create_dataset(
        fold_train_df,
        training=True,
        shuffle_seed=SEED + fold
    )

    validation_dataset = create_dataset(
        fold_validation_df
    )

    weights = compute_class_weight(
        class_weight="balanced",
        classes=np.array([0, 1]),
        y=fold_train_df["label"]
    )

    fold_class_weights = {
        0: float(weights[0]),
        1: float(weights[1])
    }

    tf.keras.backend.clear_session()
    gc.collect()

    model = build_densenet121(
        SEED + fold
    )

    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=PATIENCE,
            restore_best_weights=True,
            verbose=1
        ),

        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=2,
            min_lr=1e-7,
            verbose=1
        )
    ]

    start_time = time.time()

    history = model.fit(
        train_dataset,
        validation_data=validation_dataset,
        epochs=MAX_EPOCHS,
        class_weight=fold_class_weights,
        callbacks=callbacks,
        verbose=1
    )

    training_minutes = (
        time.time() - start_time
    ) / 60

    fold_history = pd.DataFrame(
        history.history
    )

    fold_histories[fold] = fold_history

    best_index = fold_history[
        "val_loss"
    ].idxmin()

    validation_probabilities = model.predict(
        validation_dataset,
        verbose=0
    ).ravel()

    validation_labels = fold_validation_df[
        "label"
    ].to_numpy()

    validation_predictions = (
        validation_probabilities >= 0.5
    ).astype(int)

    fold_results.append({
        "Fold": fold,
        "Epochs Trained": len(fold_history),
        "Best Epoch": best_index + 1,
        "Training Loss": fold_history.loc[
            best_index, "loss"
        ],
        "Training Accuracy": fold_history.loc[
            best_index, "accuracy"
        ],
        "Validation Loss": fold_history.loc[
            best_index, "val_loss"
        ],
        "Validation Accuracy": fold_history.loc[
            best_index, "val_accuracy"
        ],
        "Precision": precision_score(
            validation_labels,
            validation_predictions
        ),
        "Recall": recall_score(
            validation_labels,
            validation_predictions
        ),
        "F1-score": f1_score(
            validation_labels,
            validation_predictions
        ),
        "ROC-AUC": roc_auc_score(
            validation_labels,
            validation_probabilities
        ),
        "Training Minutes": training_minutes
    })

    fold_test_probabilities.append(
        model.predict(
            test_dataset,
            verbose=0
        ).ravel()
    )

    print(
        f"Fold {fold} completed in "
        f"{training_minutes:.2f} minutes"
    )

    del model
    gc.collect()
# Out:
# ==================== FOLD 1/5 ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 149s 138ms/step - accuracy: 0.5517 - loss: 0.7678 - val_accuracy: 0.5940 - val_loss: 0.6660 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 114ms/step - accuracy: 0.6390 - loss: 0.6422 - val_accuracy: 0.6908 - val_loss: 0.5987 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.6895 - loss: 0.5885 - val_accuracy: 0.7087 - val_loss: 0.5791 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 116ms/step - accuracy: 0.7144 - loss: 0.5616 - val_accuracy: 0.6857 - val_loss: 0.6046 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7204 - loss: 0.5551
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 114ms/step - accuracy: 0.7236 - loss: 0.5496 - val_accuracy: 0.6955 - val_loss: 0.5965 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7291 - loss: 0.5408 - val_accuracy: 0.6880 - val_loss: 0.6054 - learning_rate: 5.0000e-05
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 113ms/step - accuracy: 0.7317 - loss: 0.5374 - val_accuracy: 0.7132 - val_loss: 0.5739 - learning_rate: 5.0000e-05
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 112ms/step - accuracy: 0.7367 - loss: 0.5351 - val_accuracy: 0.6805 - val_loss: 0.6165 - learning_rate: 5.0000e-05
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7298 - loss: 0.5351
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7356 - loss: 0.5323 - val_accuracy: 0.7103 - val_loss: 0.5799 - learning_rate: 5.0000e-05
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 109s 117ms/step - accuracy: 0.7435 - loss: 0.5278 - val_accuracy: 0.7017 - val_loss: 0.5885 - learning_rate: 2.5000e-05
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7396 - loss: 0.5296
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7415 - loss: 0.5280 - val_accuracy: 0.6916 - val_loss: 0.6035 - learning_rate: 2.5000e-05
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7411 - loss: 0.5260 - val_accuracy: 0.7001 - val_loss: 0.5921 - learning_rate: 1.2500e-05
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Fold 1 completed in 22.00 minutes
#
# ==================== FOLD 2/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 128s 120ms/step - accuracy: 0.5353 - loss: 0.7650 - val_accuracy: 0.6660 - val_loss: 0.6283 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 114ms/step - accuracy: 0.6471 - loss: 0.6365 - val_accuracy: 0.6953 - val_loss: 0.5932 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 114ms/step - accuracy: 0.6927 - loss: 0.5882 - val_accuracy: 0.7082 - val_loss: 0.5752 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7129 - loss: 0.5617 - val_accuracy: 0.6858 - val_loss: 0.5960 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7311 - loss: 0.5440
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 114ms/step - accuracy: 0.7290 - loss: 0.5452 - val_accuracy: 0.6775 - val_loss: 0.6063 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7291 - loss: 0.5420 - val_accuracy: 0.7193 - val_loss: 0.5553 - learning_rate: 5.0000e-05
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 114ms/step - accuracy: 0.7325 - loss: 0.5384 - val_accuracy: 0.6981 - val_loss: 0.5810 - learning_rate: 5.0000e-05
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7334 - loss: 0.5394
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 114ms/step - accuracy: 0.7356 - loss: 0.5356 - val_accuracy: 0.7112 - val_loss: 0.5645 - learning_rate: 5.0000e-05
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 114ms/step - accuracy: 0.7392 - loss: 0.5302 - val_accuracy: 0.7096 - val_loss: 0.5664 - learning_rate: 2.5000e-05
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7322 - loss: 0.5324
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 114ms/step - accuracy: 0.7373 - loss: 0.5269 - val_accuracy: 0.7128 - val_loss: 0.5619 - learning_rate: 2.5000e-05
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 115ms/step - accuracy: 0.7381 - loss: 0.5297 - val_accuracy: 0.7084 - val_loss: 0.5666 - learning_rate: 1.2500e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Fold 2 completed in 19.92 minutes
#
# ==================== FOLD 3/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 128s 120ms/step - accuracy: 0.5747 - loss: 0.7159 - val_accuracy: 0.6695 - val_loss: 0.6152 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 114ms/step - accuracy: 0.6612 - loss: 0.6226 - val_accuracy: 0.6274 - val_loss: 0.6559 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 114ms/step - accuracy: 0.6930 - loss: 0.5856 - val_accuracy: 0.6745 - val_loss: 0.6105 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 114ms/step - accuracy: 0.7115 - loss: 0.5640 - val_accuracy: 0.7063 - val_loss: 0.5744 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 114ms/step - accuracy: 0.7245 - loss: 0.5479 - val_accuracy: 0.6787 - val_loss: 0.6068 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7291 - loss: 0.5452
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7349 - loss: 0.5393 - val_accuracy: 0.6755 - val_loss: 0.6113 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 108s 115ms/step - accuracy: 0.7322 - loss: 0.5371 - val_accuracy: 0.6960 - val_loss: 0.5849 - learning_rate: 5.0000e-05
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7358 - loss: 0.5361
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 114ms/step - accuracy: 0.7377 - loss: 0.5341 - val_accuracy: 0.6926 - val_loss: 0.5899 - learning_rate: 5.0000e-05
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 114ms/step - accuracy: 0.7388 - loss: 0.5295 - val_accuracy: 0.7023 - val_loss: 0.5746 - learning_rate: 2.5000e-05
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Fold 3 completed in 16.34 minutes
#
# ==================== FOLD 4/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 127s 119ms/step - accuracy: 0.5721 - loss: 0.7325 - val_accuracy: 0.6906 - val_loss: 0.5997 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.6470 - loss: 0.6334 - val_accuracy: 0.6729 - val_loss: 0.6036 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.6878 - loss: 0.5897 - val_accuracy: 0.7186 - val_loss: 0.5595 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 114ms/step - accuracy: 0.7111 - loss: 0.5666 - val_accuracy: 0.7162 - val_loss: 0.5587 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7183 - loss: 0.5524 - val_accuracy: 0.7124 - val_loss: 0.5640 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7297 - loss: 0.5439
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7297 - loss: 0.5422 - val_accuracy: 0.6932 - val_loss: 0.5891 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7324 - loss: 0.5346 - val_accuracy: 0.7032 - val_loss: 0.5778 - learning_rate: 5.0000e-05
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7341 - loss: 0.5353
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 105s 112ms/step - accuracy: 0.7360 - loss: 0.5330 - val_accuracy: 0.7029 - val_loss: 0.5781 - learning_rate: 5.0000e-05
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7346 - loss: 0.5333 - val_accuracy: 0.6888 - val_loss: 0.5943 - learning_rate: 2.5000e-05
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Fold 4 completed in 16.23 minutes
#
# ==================== FOLD 5/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 126s 118ms/step - accuracy: 0.5848 - loss: 0.7131 - val_accuracy: 0.6941 - val_loss: 0.6041 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.6504 - loss: 0.6352 - val_accuracy: 0.6781 - val_loss: 0.6125 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6763 - loss: 0.6011
# Epoch 3: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.6895 - loss: 0.5889 - val_accuracy: 0.6832 - val_loss: 0.6050 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7070 - loss: 0.5701 - val_accuracy: 0.6766 - val_loss: 0.6131 - learning_rate: 5.0000e-05
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 114ms/step - accuracy: 0.7153 - loss: 0.5594 - val_accuracy: 0.6868 - val_loss: 0.6021 - learning_rate: 5.0000e-05
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7197 - loss: 0.5564 - val_accuracy: 0.6943 - val_loss: 0.5916 - learning_rate: 5.0000e-05
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7256 - loss: 0.5486 - val_accuracy: 0.6981 - val_loss: 0.5895 - learning_rate: 5.0000e-05
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 114ms/step - accuracy: 0.7256 - loss: 0.5434 - val_accuracy: 0.7044 - val_loss: 0.5816 - learning_rate: 5.0000e-05
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 107s 114ms/step - accuracy: 0.7305 - loss: 0.5396 - val_accuracy: 0.7198 - val_loss: 0.5625 - learning_rate: 5.0000e-05
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7373 - loss: 0.5350 - val_accuracy: 0.7035 - val_loss: 0.5797 - learning_rate: 5.0000e-05
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7342 - loss: 0.5352
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7367 - loss: 0.5316 - val_accuracy: 0.6953 - val_loss: 0.5915 - learning_rate: 5.0000e-05
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 114ms/step - accuracy: 0.7397 - loss: 0.5300 - val_accuracy: 0.7048 - val_loss: 0.5781 - learning_rate: 2.5000e-05
# Epoch 13/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7402 - loss: 0.5265
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.7385 - loss: 0.5311 - val_accuracy: 0.6988 - val_loss: 0.5859 - learning_rate: 2.5000e-05
# Epoch 14/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 106s 114ms/step - accuracy: 0.7411 - loss: 0.5258 - val_accuracy: 0.7061 - val_loss: 0.5779 - learning_rate: 1.2500e-05
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Fold 5 completed in 25.11 minutes

# %%
fold_results_df = pd.DataFrame(
    fold_results
)

display(
    fold_results_df.round(4)
)
# Out:
#    Fold  Epochs Trained  Best Epoch  Training Loss  Training Accuracy  \
# 0     1              12           7         0.5374             0.7317
# 1     2              11           6         0.5420             0.7291
# 2     3               9           4         0.5640             0.7115
# 3     4               9           4         0.5666             0.7111
# 4     5              14           9         0.5396             0.7305
#
#    Validation Loss  Validation Accuracy  Precision  Recall  F1-score  ROC-AUC  \
# 0           0.5739               0.7132     0.9114  0.6597    0.7654   0.8408
# 1           0.5553               0.7193     0.9101  0.6702    0.7720   0.8448
# 2           0.5744               0.7063     0.9068  0.6529    0.7592   0.8332
# 3           0.5587               0.7162     0.8997  0.6750    0.7713   0.8348
# 4           0.5625               0.7198     0.9158  0.6661    0.7712   0.8431
#
#    Training Minutes
# 0           21.9975
# 1           19.9165
# 2           16.3439
# 3           16.2251
# 4           25.1070

# %%
summary_columns = [
    "Training Loss",
    "Training Accuracy",
    "Validation Loss",
    "Validation Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "ROC-AUC"
]

cv_summary_df = pd.DataFrame({
    "Mean": fold_results_df[
        summary_columns
    ].mean(),

    "Standard Deviation": fold_results_df[
        summary_columns
    ].std()
})

display(
    cv_summary_df.round(4)
)
# Out:
#                        Mean  Standard Deviation
# Training Loss        0.5499              0.0142
# Training Accuracy    0.7228              0.0105
# Validation Loss      0.5650              0.0088
# Validation Accuracy  0.7149              0.0055
# Precision            0.9088              0.0060
# Recall               0.6648              0.0087
# F1-score             0.7678              0.0055
# ROC-AUC              0.8394              0.0051

# %%
test_probabilities_cv = np.mean(
    np.vstack(
        fold_test_probabilities
    ),
    axis=0
)

test_predictions_cv = (
    test_probabilities_cv >= 0.5
).astype(int)

true_test_labels = test_df[
    "label"
].to_numpy()

print("Test images:", len(true_test_labels))
print(
    "Ensemble predictions:",
    len(test_predictions_cv)
)
# Out:
# Test images: 6600
# Ensemble predictions: 6600

# %%
from sklearn.metrics import (
    log_loss,
    accuracy_score
)

test_loss_cv = log_loss(
    true_test_labels,
    test_probabilities_cv
)

test_accuracy_cv = accuracy_score(
    true_test_labels,
    test_predictions_cv
)

print(
    "Test Loss:",
    round(test_loss_cv, 4)
)

print(
    "Test Accuracy:",
    round(test_accuracy_cv, 4)
)
# Out:
# Test Loss: 0.5575
# Test Accuracy: 0.7217

# %%
test_precision_cv = precision_score(
    true_test_labels,
    test_predictions_cv
)

test_recall_cv = recall_score(
    true_test_labels,
    test_predictions_cv
)

test_f1_cv = f1_score(
    true_test_labels,
    test_predictions_cv
)

test_auc_cv = roc_auc_score(
    true_test_labels,
    test_probabilities_cv
)

print("Precision:", round(test_precision_cv, 4))
print("Recall:", round(test_recall_cv, 4))
print("F1-score:", round(test_f1_cv, 4))
print("ROC-AUC:", round(test_auc_cv, 4))
# Out:
# Precision: 0.9046
# Recall: 0.6791
# F1-score: 0.7758
# ROC-AUC: 0.8431

# %%
from sklearn.metrics import confusion_matrix

cm_cv = confusion_matrix(
    true_test_labels,
    test_predictions_cv
)

plt.figure(figsize=(7, 5))

sns.heatmap(
    cm_cv,
    annot=True,
    fmt="d",
    cmap="Greens",
    xticklabels=[
        "NonDemented",
        "Demented"
    ],
    yticklabels=[
        "NonDemented",
        "Demented"
    ]
)

plt.title(
    "DenseNet121 5-Fold CV Test Confusion Matrix"
)

plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.tight_layout()
plt.show()

# %%
mean_validation_accuracy = (
    fold_results_df[
        "Validation Accuracy"
    ].mean()
)

plt.figure(figsize=(8, 5))

bars = plt.bar(
    fold_results_df["Fold"],
    fold_results_df[
        "Validation Accuracy"
    ],
    color="seagreen"
)

plt.axhline(
    mean_validation_accuracy,
    color="red",
    linestyle="--",
    label=(
        f"Mean = "
        f"{mean_validation_accuracy:.4f}"
    )
)

for bar, value in zip(
    bars,
    fold_results_df[
        "Validation Accuracy"
    ]
):
    plt.text(
        bar.get_x()
        + bar.get_width() / 2,
        value + 0.003,
        f"{value:.4f}",
        ha="center"
    )

plt.ylim(0, 1)
plt.title(
    "DenseNet121 Validation Accuracy Across Five Folds"
)
plt.xlabel("Fold")
plt.ylabel("Validation Accuracy")
plt.xticks(fold_results_df["Fold"])
plt.legend()
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

for fold, fold_history in fold_histories.items():
    epochs = range(
        1,
        len(fold_history) + 1
    )

    plt.plot(
        epochs,
        fold_history["loss"],
        label=f"Fold {fold} Training"
    )

    plt.plot(
        epochs,
        fold_history["val_loss"],
        linestyle="--",
        label=f"Fold {fold} Validation"
    )

plt.title(
    "DenseNet121 Training and Validation Loss Across Five Folds"
)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(ncol=2, fontsize=9)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

for fold, fold_history in fold_histories.items():
    epochs = range(
        1,
        len(fold_history) + 1
    )

    plt.plot(
        epochs,
        fold_history["accuracy"],
        label=f"Fold {fold} Training"
    )

    plt.plot(
        epochs,
        fold_history["val_accuracy"],
        linestyle="--",
        label=f"Fold {fold} Validation"
    )

plt.title(
    "DenseNet121 Training and Validation Accuracy Across Five Folds"
)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(ncol=2, fontsize=9)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve

fpr_cv, tpr_cv, _ = roc_curve(
    true_test_labels,
    test_probabilities_cv
)

plt.figure(figsize=(7, 5))

plt.plot(
    fpr_cv,
    tpr_cv,
    label=(
        f"DenseNet121 5-Fold CV "
        f"(AUC = {test_auc_cv:.4f})"
    )
)

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--",
    color="gray",
    label="Random Classifier"
)

plt.title(
    "DenseNet121 5-Fold CV Test ROC Curve"
)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
sample_indices = np.random.default_rng(
    SEED
).choice(
    len(test_df),
    size=12,
    replace=False
)

plt.figure(figsize=(16, 12))

for position, index in enumerate(
    sample_indices,
    start=1
):
    image = tf.keras.utils.load_img(
        test_df.iloc[index]["filepath"],
        target_size=IMG_SIZE
    )

    actual = true_test_labels[index]
    predicted = test_predictions_cv[index]
    probability = test_probabilities_cv[index]

    actual_name = (
        "Demented"
        if actual == 1
        else "NonDemented"
    )

    predicted_name = (
        "Demented"
        if predicted == 1
        else "NonDemented"
    )

    title_color = (
        "green"
        if actual == predicted
        else "red"
    )

    plt.subplot(3, 4, position)
    plt.imshow(image)

    plt.title(
        f"Actual: {actual_name}\n"
        f"Predicted: {predicted_name}\n"
        f"Probability: {probability:.3f}",
        color=title_color,
        fontsize=10
    )

    plt.axis("off")

plt.suptitle(
    "DenseNet121 5-Fold CV Sanity Test",
    fontsize=16
)

plt.tight_layout()
plt.show()

# %%
test_results_df = pd.DataFrame({
    "Model": ["DenseNet121"],
    "Cross-Validation": ["5-Fold"],
    "Test Loss": [test_loss_cv],
    "Accuracy": [test_accuracy_cv],
    "Precision": [test_precision_cv],
    "Recall": [test_recall_cv],
    "F1-score": [test_f1_cv],
    "ROC-AUC": [test_auc_cv]
})

all_histories_df = pd.concat(
    [
        history.assign(
            Fold=fold,
            Epoch=range(1, len(history) + 1)
        )
        for fold, history
        in fold_histories.items()
    ],
    ignore_index=True
)

fold_results_df.to_csv(
    "/kaggle/working/densenet121_cv_fold_results.csv",
    index=False
)

cv_summary_df.to_csv(
    "/kaggle/working/densenet121_cv_summary.csv"
)

test_results_df.to_csv(
    "/kaggle/working/densenet121_cv_test_results.csv",
    index=False
)

all_histories_df.to_csv(
    "/kaggle/working/densenet121_cv_training_history.csv",
    index=False
)

display(test_results_df.round(4))

print("All DenseNet121 CV result files saved.")
# Out:
#          Model Cross-Validation  Test Loss  Accuracy  Precision  Recall  \
# 0  DenseNet121           5-Fold     0.5575    0.7217     0.9046  0.6791
#
#    F1-score  ROC-AUC
# 0    0.7758   0.8431
# All DenseNet121 CV result files saved.
