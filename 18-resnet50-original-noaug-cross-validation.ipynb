# %%
import os
import gc
import time
import random
from pathlib import Path

import kagglehub
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow version:", tf.__version__)
print("Available GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow version: 2.20.0
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
dataset_path = Path(
    kagglehub.dataset_download(
        "aryansinghal10/alzheimers-multiclass-dataset-equal-and-augmented"
    )
)

image_root = dataset_path / "combined_images"

print("Dataset path:", dataset_path)
print("Image folder:", image_root)
print("Image folder exists:", image_root.exists())
# Out:
# Dataset path: /kaggle/input/datasets/aryansinghal10/alzheimers-multiclass-dataset-equal-and-augmented
# Image folder: /kaggle/input/datasets/aryansinghal10/alzheimers-multiclass-dataset-equal-and-augmented/combined_images
# Image folder exists: True

# %%
class_to_binary = {
    "NonDemented": 0,
    "VeryMildDemented": 1,
    "MildDemented": 1,
    "ModerateDemented": 1
}

records = []

for class_name, binary_label in class_to_binary.items():
    class_folder = image_root / class_name

    for image_path in sorted(class_folder.iterdir()):
        if image_path.suffix.lower() in {".jpg", ".jpeg", ".png"}:
            records.append({
                "filepath": str(image_path),
                "original_class": class_name,
                "label": binary_label
            })

df = pd.DataFrame(records)

print("Total images:", len(df))
print("\nBinary class counts:")
print(df["label"].value_counts().sort_index())

print("\nOriginal class counts:")
print(df["original_class"].value_counts())
# Out:
# Total images: 44000
#
# Binary class counts:
# label
# 0    12800
# 1    31200
# Name: count, dtype: int64
#
# Original class counts:
# original_class
# NonDemented         12800
# VeryMildDemented    11200
# MildDemented        10000
# ModerateDemented    10000
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

initial_train_df, temporary_df = train_test_split(
    df,
    test_size=0.30,
    stratify=df["label"],
    random_state=SEED
)

initial_validation_df, test_df = train_test_split(
    temporary_df,
    test_size=0.50,
    stratify=temporary_df["label"],
    random_state=SEED
)

development_df = pd.concat(
    [initial_train_df, initial_validation_df],
    ignore_index=True
)

development_df = development_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

print("Development images:", len(development_df))
print(development_df["label"].value_counts().sort_index())

print("\nUntouched test images:", len(test_df))
print(test_df["label"].value_counts().sort_index())
# Out:
# Development images: 37400
# label
# 0    10880
# 1    26520
# Name: count, dtype: int64
#
# Untouched test images: 6600
# label
# 0    1920
# 1    4680
# Name: count, dtype: int64

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

def load_original_image(filepath, label):
    image = tf.io.read_file(filepath)

    image = tf.io.decode_image(
        image,
        channels=3,
        expand_animations=False
    )
    image.set_shape([None, None, 3])

    image = tf.image.resize(image, IMG_SIZE)
    image = tf.cast(image, tf.float32)
    label = tf.cast(label, tf.float32)

    return image, label


def create_original_dataset(
    dataframe,
    training=False,
    shuffle_seed=SEED
):
    dataset = tf.data.Dataset.from_tensor_slices(
        (
            dataframe["filepath"].values,
            dataframe["label"].values
        )
    )

    if training:
        dataset = dataset.shuffle(
            buffer_size=min(len(dataframe), 10000),
            seed=shuffle_seed,
            reshuffle_each_iteration=True
        )

    dataset = dataset.map(
        load_original_image,
        num_parallel_calls=AUTOTUNE
    )

    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE)

    return dataset


test_dataset = create_original_dataset(test_df)

for images, labels in test_dataset.take(1):
    print("Image batch shape:", images.shape)
    print("Label batch shape:", labels.shape)
    print("Pixel range:", images.numpy().min(), "to", images.numpy().max())
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787757320.320543      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Image batch shape: (32, 224, 224, 3)
# Label batch shape: (32,)
# Pixel range: 0.0 to 255.0

# %%
from sklearn.model_selection import StratifiedKFold

MAX_EPOCHS = 30
PATIENCE = 5
LEARNING_RATE = 0.0001
N_FOLDS = 5

cross_validator = StratifiedKFold(
    n_splits=N_FOLDS,
    shuffle=True,
    random_state=SEED
)

for fold, (train_indices, validation_indices) in enumerate(
    cross_validator.split(
        development_df,
        development_df["label"]
    ),
    start=1
):
    fold_train_df = development_df.iloc[train_indices]
    fold_validation_df = development_df.iloc[validation_indices]

    print(
        f"Fold {fold}: "
        f"Training = {len(fold_train_df)}, "
        f"Validation = {len(fold_validation_df)}"
    )

print("\nMaximum epochs:", MAX_EPOCHS)
print("Early-stopping patience:", PATIENCE)
print("Learning rate:", LEARNING_RATE)
print("Augmentation: Disabled")
print("Preprocessing: None")
# Out:
# Fold 1: Training = 29920, Validation = 7480
# Fold 2: Training = 29920, Validation = 7480
# Fold 3: Training = 29920, Validation = 7480
# Fold 4: Training = 29920, Validation = 7480
# Fold 5: Training = 29920, Validation = 7480
#
# Maximum epochs: 30
# Early-stopping patience: 5
# Learning rate: 0.0001
# Augmentation: Disabled
# Preprocessing: None

# %%
def build_resnet50(fold_seed):
    tf.keras.utils.set_random_seed(fold_seed)

    resnet_base = tf.keras.applications.ResNet50(
        weights="imagenet",
        include_top=False,
        input_shape=(224, 224, 3)
    )

    resnet_base.trainable = False

    inputs = tf.keras.Input(shape=(224, 224, 3))

    x = tf.keras.applications.resnet50.preprocess_input(inputs)
    x = resnet_base(x, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.30)(x)

    outputs = tf.keras.layers.Dense(
        1,
        activation="sigmoid"
    )(x)

    model = tf.keras.Model(
        inputs=inputs,
        outputs=outputs,
        name="ResNet50_Original_NoAug_CV"
    )

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=LEARNING_RATE
        ),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model


sample_model = build_resnet50(SEED)

print("Total parameters:", sample_model.count_params())
print(
    "Trainable parameters:",
    sum(
        tf.keras.backend.count_params(weight)
        for weight in sample_model.trainable_weights
    )
)
print(
    "ResNet50 frozen:",
    not sample_model.get_layer("resnet50").trainable
)

del sample_model
tf.keras.backend.clear_session()
gc.collect()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Total parameters: 23589761
# Trainable parameters: 2049
# ResNet50 frozen: True
# 0

# %%
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)

fold_histories = {}
fold_results = []
fold_test_probabilities = []
fold_model_paths = []

print("Cross-validation storage initialized.")
# Out:
# Cross-validation storage initialized.

# %%
for fold, (train_indices, validation_indices) in enumerate(
    cross_validator.split(
        development_df,
        development_df["label"]
    ),
    start=1
):
    print(
        f"\n{'=' * 20} "
        f"FOLD {fold}/{N_FOLDS} "
        f"{'=' * 20}"
    )

    fold_train_df = development_df.iloc[
        train_indices
    ].reset_index(drop=True)

    fold_validation_df = development_df.iloc[
        validation_indices
    ].reset_index(drop=True)

    train_dataset = create_original_dataset(
        fold_train_df,
        training=True,
        shuffle_seed=SEED + fold
    )

    validation_dataset = create_original_dataset(
        fold_validation_df
    )

    weights = compute_class_weight(
        class_weight="balanced",
        classes=np.array([0, 1]),
        y=fold_train_df["label"]
    )

    fold_class_weights = {
        0: float(weights[0]),
        1: float(weights[1])
    }

    tf.keras.backend.clear_session()
    gc.collect()

    model = build_resnet50(SEED + fold)

    model_path = (
        f"/kaggle/working/"
        f"resnet50_original_noaug_cv_fold_{fold}.keras"
    )

    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=PATIENCE,
            restore_best_weights=True,
            verbose=1
        ),

        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=2,
            min_lr=1e-7,
            verbose=1
        ),

        tf.keras.callbacks.ModelCheckpoint(
            model_path,
            monitor="val_loss",
            save_best_only=True,
            verbose=1
        )
    ]

    start_time = time.time()

    history = model.fit(
        train_dataset,
        validation_data=validation_dataset,
        epochs=MAX_EPOCHS,
        class_weight=fold_class_weights,
        callbacks=callbacks,
        verbose=1
    )

    training_minutes = (
        time.time() - start_time
    ) / 60

    history_df = pd.DataFrame(history.history)
    best_index = history_df["val_loss"].idxmin()

    fold_histories[fold] = history_df
    fold_model_paths.append(model_path)

    validation_probabilities = model.predict(
        validation_dataset,
        verbose=0
    ).ravel()

    validation_predictions = (
        validation_probabilities >= 0.5
    ).astype(int)

    validation_labels = fold_validation_df[
        "label"
    ].to_numpy()

    fold_results.append({
        "Fold": fold,
        "Epochs Trained": len(history_df),
        "Best Epoch": best_index + 1,
        "Training Loss": history_df.loc[
            best_index, "loss"
        ],
        "Training Accuracy": history_df.loc[
            best_index, "accuracy"
        ],
        "Validation Loss": history_df.loc[
            best_index, "val_loss"
        ],
        "Validation Accuracy": accuracy_score(
            validation_labels,
            validation_predictions
        ),
        "Precision": precision_score(
            validation_labels,
            validation_predictions
        ),
        "Recall": recall_score(
            validation_labels,
            validation_predictions
        ),
        "F1-score": f1_score(
            validation_labels,
            validation_predictions
        ),
        "ROC-AUC": roc_auc_score(
            validation_labels,
            validation_probabilities
        ),
        "Training Minutes": training_minutes
    })

    fold_test_probabilities.append(
        model.predict(
            test_dataset,
            verbose=0
        ).ravel()
    )

    print(
        f"Fold {fold} completed in "
        f"{training_minutes:.2f} minutes"
    )

    del model, train_dataset, validation_dataset
    tf.keras.backend.clear_session()
    gc.collect()
# Out:
# ==================== FOLD 1/5 ====================
# Epoch 1/30
#   3/935 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.5590 - loss: 1.0222
# I0000 00:00:1787757451.472525     137 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5695 - loss: 0.7367
# Epoch 1: val_loss improved from None to 0.50947, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_1.keras
#
# Epoch 1: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_1.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 71s 63ms/step - accuracy: 0.6314 - loss: 0.6616 - val_accuracy: 0.7655 - val_loss: 0.5095 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7166 - loss: 0.5609
# Epoch 2: val_loss improved from 0.50947 to 0.50343, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_1.keras
#
# Epoch 2: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_1.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7241 - loss: 0.5489 - val_accuracy: 0.7568 - val_loss: 0.5034 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7435 - loss: 0.5197
# Epoch 3: val_loss improved from 0.50343 to 0.47155, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_1.keras
#
# Epoch 3: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_1.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7508 - loss: 0.5105 - val_accuracy: 0.7762 - val_loss: 0.4716 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7629 - loss: 0.4943
# Epoch 4: val_loss did not improve from 0.47155
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 52ms/step - accuracy: 0.7617 - loss: 0.4924 - val_accuracy: 0.7666 - val_loss: 0.4834 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7656 - loss: 0.4829
# Epoch 5: val_loss improved from 0.47155 to 0.45674, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_1.keras
#
# Epoch 5: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_1.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7655 - loss: 0.4813 - val_accuracy: 0.7849 - val_loss: 0.4567 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7713 - loss: 0.4707
# Epoch 6: val_loss improved from 0.45674 to 0.45001, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_1.keras
#
# Epoch 6: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_1.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7715 - loss: 0.4705 - val_accuracy: 0.7868 - val_loss: 0.4500 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7738 - loss: 0.4686
# Epoch 7: val_loss improved from 0.45001 to 0.41768, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_1.keras
#
# Epoch 7: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_1.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7753 - loss: 0.4656 - val_accuracy: 0.8071 - val_loss: 0.4177 - learning_rate: 1.0000e-04
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7827 - loss: 0.4569
# Epoch 8: val_loss did not improve from 0.41768
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 52ms/step - accuracy: 0.7794 - loss: 0.4599 - val_accuracy: 0.8043 - val_loss: 0.4225 - learning_rate: 1.0000e-04
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7820 - loss: 0.4603
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 9: val_loss did not improve from 0.41768
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 52ms/step - accuracy: 0.7821 - loss: 0.4555 - val_accuracy: 0.8033 - val_loss: 0.4279 - learning_rate: 1.0000e-04
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7871 - loss: 0.4475
# Epoch 10: val_loss did not improve from 0.41768
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 52ms/step - accuracy: 0.7860 - loss: 0.4503 - val_accuracy: 0.7864 - val_loss: 0.4505 - learning_rate: 5.0000e-05
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7863 - loss: 0.4515
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 11: val_loss did not improve from 0.41768
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 52ms/step - accuracy: 0.7851 - loss: 0.4505 - val_accuracy: 0.7900 - val_loss: 0.4435 - learning_rate: 5.0000e-05
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7858 - loss: 0.4445
# Epoch 12: val_loss did not improve from 0.41768
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 52ms/step - accuracy: 0.7853 - loss: 0.4467 - val_accuracy: 0.7929 - val_loss: 0.4399 - learning_rate: 2.5000e-05
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Fold 1 completed in 10.26 minutes
#
# ==================== FOLD 2/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6176 - loss: 0.6820
# Epoch 1: val_loss improved from None to 0.49193, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_2.keras
#
# Epoch 1: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_2.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.6559 - loss: 0.6342 - val_accuracy: 0.7783 - val_loss: 0.4919 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7231 - loss: 0.5547
# Epoch 2: val_loss improved from 0.49193 to 0.46079, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_2.keras
#
# Epoch 2: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_2.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7301 - loss: 0.5426 - val_accuracy: 0.7868 - val_loss: 0.4608 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7516 - loss: 0.5163
# Epoch 3: val_loss did not improve from 0.46079
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7513 - loss: 0.5114 - val_accuracy: 0.7737 - val_loss: 0.4776 - learning_rate: 1.0000e-04
# Epoch 4/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7562 - loss: 0.4976
# Epoch 4: val_loss improved from 0.46079 to 0.44035, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_2.keras
#
# Epoch 4: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_2.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 51s 54ms/step - accuracy: 0.7577 - loss: 0.4964 - val_accuracy: 0.7952 - val_loss: 0.4404 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7647 - loss: 0.4905
# Epoch 5: val_loss improved from 0.44035 to 0.43968, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_2.keras
#
# Epoch 5: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_2.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 51s 54ms/step - accuracy: 0.7675 - loss: 0.4861 - val_accuracy: 0.7920 - val_loss: 0.4397 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7688 - loss: 0.4745
# Epoch 6: val_loss improved from 0.43968 to 0.42838, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_2.keras
#
# Epoch 6: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_2.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7710 - loss: 0.4735 - val_accuracy: 0.8011 - val_loss: 0.4284 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7733 - loss: 0.4681
# Epoch 7: val_loss did not improve from 0.42838
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7740 - loss: 0.4679 - val_accuracy: 0.7678 - val_loss: 0.4804 - learning_rate: 1.0000e-04
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7755 - loss: 0.4633
# Epoch 8: val_loss improved from 0.42838 to 0.41033, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_2.keras
#
# Epoch 8: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_2.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7776 - loss: 0.4606 - val_accuracy: 0.8110 - val_loss: 0.4103 - learning_rate: 1.0000e-04
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7833 - loss: 0.4558
# Epoch 9: val_loss did not improve from 0.41033
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7790 - loss: 0.4583 - val_accuracy: 0.7999 - val_loss: 0.4246 - learning_rate: 1.0000e-04
# Epoch 10/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7771 - loss: 0.4583
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 10: val_loss did not improve from 0.41033
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7821 - loss: 0.4533 - val_accuracy: 0.7963 - val_loss: 0.4329 - learning_rate: 1.0000e-04
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7814 - loss: 0.4563
# Epoch 11: val_loss did not improve from 0.41033
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7847 - loss: 0.4514 - val_accuracy: 0.8009 - val_loss: 0.4250 - learning_rate: 5.0000e-05
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7880 - loss: 0.4502
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 12: val_loss did not improve from 0.41033
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7863 - loss: 0.4484 - val_accuracy: 0.8028 - val_loss: 0.4224 - learning_rate: 5.0000e-05
# Epoch 13/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7870 - loss: 0.4457
# Epoch 13: val_loss did not improve from 0.41033
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7866 - loss: 0.4460 - val_accuracy: 0.8057 - val_loss: 0.4156 - learning_rate: 2.5000e-05
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Fold 2 completed in 11.05 minutes
#
# ==================== FOLD 3/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5528 - loss: 0.7600
# Epoch 1: val_loss improved from None to 0.53046, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
#
# Epoch 1: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 66s 60ms/step - accuracy: 0.6222 - loss: 0.6780 - val_accuracy: 0.7511 - val_loss: 0.5305 - learning_rate: 1.0000e-04
# Epoch 2/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7142 - loss: 0.5628
# Epoch 2: val_loss improved from 0.53046 to 0.48808, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
#
# Epoch 2: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 51s 54ms/step - accuracy: 0.7218 - loss: 0.5537 - val_accuracy: 0.7717 - val_loss: 0.4881 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7414 - loss: 0.5208
# Epoch 3: val_loss improved from 0.48808 to 0.44848, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
#
# Epoch 3: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 51s 54ms/step - accuracy: 0.7447 - loss: 0.5154 - val_accuracy: 0.7930 - val_loss: 0.4485 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7596 - loss: 0.4994
# Epoch 4: val_loss did not improve from 0.44848
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7593 - loss: 0.4982 - val_accuracy: 0.7635 - val_loss: 0.4876 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7675 - loss: 0.4852
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 5: val_loss improved from 0.44848 to 0.44842, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
#
# Epoch 5: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7655 - loss: 0.4848 - val_accuracy: 0.7856 - val_loss: 0.4484 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7744 - loss: 0.4727
# Epoch 6: val_loss did not improve from 0.44842
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7705 - loss: 0.4744 - val_accuracy: 0.7856 - val_loss: 0.4488 - learning_rate: 5.0000e-05
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7737 - loss: 0.4702
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 7: val_loss did not improve from 0.44842
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7728 - loss: 0.4710 - val_accuracy: 0.7789 - val_loss: 0.4579 - learning_rate: 5.0000e-05
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7779 - loss: 0.4643
# Epoch 8: val_loss did not improve from 0.44842
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7756 - loss: 0.4667 - val_accuracy: 0.7783 - val_loss: 0.4583 - learning_rate: 2.5000e-05
# Epoch 9/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7768 - loss: 0.4599
# Epoch 9: val_loss improved from 0.44842 to 0.44575, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
#
# Epoch 9: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 51s 54ms/step - accuracy: 0.7760 - loss: 0.4651 - val_accuracy: 0.7874 - val_loss: 0.4457 - learning_rate: 2.5000e-05
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7756 - loss: 0.4635
# Epoch 10: val_loss did not improve from 0.44575
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7761 - loss: 0.4653 - val_accuracy: 0.7761 - val_loss: 0.4602 - learning_rate: 2.5000e-05
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7845 - loss: 0.4551
# Epoch 11: val_loss improved from 0.44575 to 0.44026, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
#
# Epoch 11: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7777 - loss: 0.4637 - val_accuracy: 0.7910 - val_loss: 0.4403 - learning_rate: 2.5000e-05
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7792 - loss: 0.4604
# Epoch 12: val_loss improved from 0.44026 to 0.43734, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
#
# Epoch 12: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7776 - loss: 0.4614 - val_accuracy: 0.7922 - val_loss: 0.4373 - learning_rate: 2.5000e-05
# Epoch 13/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7850 - loss: 0.4538
# Epoch 13: val_loss improved from 0.43734 to 0.43447, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
#
# Epoch 13: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7794 - loss: 0.4601 - val_accuracy: 0.7940 - val_loss: 0.4345 - learning_rate: 2.5000e-05
# Epoch 14/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7828 - loss: 0.4528
# Epoch 14: val_loss did not improve from 0.43447
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7814 - loss: 0.4565 - val_accuracy: 0.7774 - val_loss: 0.4572 - learning_rate: 2.5000e-05
# Epoch 15/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7813 - loss: 0.4539
# Epoch 15: val_loss improved from 0.43447 to 0.43375, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
#
# Epoch 15: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_3.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7793 - loss: 0.4563 - val_accuracy: 0.7947 - val_loss: 0.4338 - learning_rate: 2.5000e-05
# Epoch 16/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7832 - loss: 0.4521
# Epoch 16: val_loss did not improve from 0.43375
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7816 - loss: 0.4552 - val_accuracy: 0.7854 - val_loss: 0.4438 - learning_rate: 2.5000e-05
# Epoch 17/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7835 - loss: 0.4514
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 17: val_loss did not improve from 0.43375
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7817 - loss: 0.4550 - val_accuracy: 0.7898 - val_loss: 0.4386 - learning_rate: 2.5000e-05
# Epoch 18/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7872 - loss: 0.4481
# Epoch 18: val_loss did not improve from 0.43375
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7810 - loss: 0.4547 - val_accuracy: 0.7801 - val_loss: 0.4492 - learning_rate: 1.2500e-05
# Epoch 19/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7884 - loss: 0.4498
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 19: val_loss did not improve from 0.43375
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7841 - loss: 0.4545 - val_accuracy: 0.7820 - val_loss: 0.4460 - learning_rate: 1.2500e-05
# Epoch 20/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7834 - loss: 0.4521
# Epoch 20: val_loss did not improve from 0.43375
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7839 - loss: 0.4537 - val_accuracy: 0.7825 - val_loss: 0.4455 - learning_rate: 6.2500e-06
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Fold 3 completed in 16.91 minutes
#
# ==================== FOLD 4/5 ====================
# Epoch 1/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5823 - loss: 0.7056
# Epoch 1: val_loss improved from None to 0.50251, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_4.keras
#
# Epoch 1: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_4.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 66s 60ms/step - accuracy: 0.6373 - loss: 0.6450 - val_accuracy: 0.7726 - val_loss: 0.5025 - learning_rate: 1.0000e-04
# Epoch 2/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7236 - loss: 0.5560
# Epoch 2: val_loss improved from 0.50251 to 0.48434, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_4.keras
#
# Epoch 2: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_4.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 51s 54ms/step - accuracy: 0.7287 - loss: 0.5447 - val_accuracy: 0.7745 - val_loss: 0.4843 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7475 - loss: 0.5194
# Epoch 3: val_loss improved from 0.48434 to 0.46248, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_4.keras
#
# Epoch 3: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_4.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7513 - loss: 0.5097 - val_accuracy: 0.7853 - val_loss: 0.4625 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7571 - loss: 0.5005
# Epoch 4: val_loss improved from 0.46248 to 0.44820, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_4.keras
#
# Epoch 4: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_4.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7616 - loss: 0.4931 - val_accuracy: 0.7933 - val_loss: 0.4482 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7675 - loss: 0.4841
# Epoch 5: val_loss did not improve from 0.44820
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7671 - loss: 0.4813 - val_accuracy: 0.7821 - val_loss: 0.4586 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7703 - loss: 0.4769
# Epoch 6: val_loss improved from 0.44820 to 0.43195, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_4.keras
#
# Epoch 6: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_4.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7745 - loss: 0.4720 - val_accuracy: 0.8031 - val_loss: 0.4320 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7767 - loss: 0.4654
# Epoch 7: val_loss did not improve from 0.43195
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7745 - loss: 0.4656 - val_accuracy: 0.7940 - val_loss: 0.4369 - learning_rate: 1.0000e-04
# Epoch 8/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7830 - loss: 0.4588
# Epoch 8: val_loss improved from 0.43195 to 0.42238, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_4.keras
#
# Epoch 8: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_4.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 51s 54ms/step - accuracy: 0.7799 - loss: 0.4598 - val_accuracy: 0.8059 - val_loss: 0.4224 - learning_rate: 1.0000e-04
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7816 - loss: 0.4591
# Epoch 9: val_loss did not improve from 0.42238
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7818 - loss: 0.4563 - val_accuracy: 0.8003 - val_loss: 0.4272 - learning_rate: 1.0000e-04
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7822 - loss: 0.4584
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 10: val_loss did not improve from 0.42238
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7835 - loss: 0.4528 - val_accuracy: 0.7989 - val_loss: 0.4269 - learning_rate: 1.0000e-04
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7833 - loss: 0.4507
# Epoch 11: val_loss did not improve from 0.42238
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7851 - loss: 0.4498 - val_accuracy: 0.7856 - val_loss: 0.4470 - learning_rate: 5.0000e-05
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7864 - loss: 0.4489
# Epoch 12: val_loss improved from 0.42238 to 0.42067, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_4.keras
#
# Epoch 12: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_4.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 51s 54ms/step - accuracy: 0.7881 - loss: 0.4478 - val_accuracy: 0.8043 - val_loss: 0.4207 - learning_rate: 5.0000e-05
# Epoch 13/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7922 - loss: 0.4424
# Epoch 13: val_loss did not improve from 0.42067
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7864 - loss: 0.4469 - val_accuracy: 0.7973 - val_loss: 0.4301 - learning_rate: 5.0000e-05
# Epoch 14/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7885 - loss: 0.4433
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 14: val_loss did not improve from 0.42067
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7857 - loss: 0.4458 - val_accuracy: 0.7897 - val_loss: 0.4403 - learning_rate: 5.0000e-05
# Epoch 15/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7855 - loss: 0.4455
# Epoch 15: val_loss did not improve from 0.42067
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7868 - loss: 0.4426 - val_accuracy: 0.8003 - val_loss: 0.4236 - learning_rate: 2.5000e-05
# Epoch 16/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7897 - loss: 0.4404
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 16: val_loss did not improve from 0.42067
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7876 - loss: 0.4430 - val_accuracy: 0.7912 - val_loss: 0.4364 - learning_rate: 2.5000e-05
# Epoch 17/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7938 - loss: 0.4373
# Epoch 17: val_loss did not improve from 0.42067
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7903 - loss: 0.4416 - val_accuracy: 0.7933 - val_loss: 0.4345 - learning_rate: 1.2500e-05
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Fold 4 completed in 14.39 minutes
#
# ==================== FOLD 5/5 ====================
# Epoch 1/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5720 - loss: 0.7115
# Epoch 1: val_loss improved from None to 0.51345, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
#
# Epoch 1: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 66s 60ms/step - accuracy: 0.6337 - loss: 0.6497 - val_accuracy: 0.7644 - val_loss: 0.5134 - learning_rate: 1.0000e-04
# Epoch 2/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7166 - loss: 0.5626
# Epoch 2: val_loss improved from 0.51345 to 0.49669, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
#
# Epoch 2: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 51s 54ms/step - accuracy: 0.7291 - loss: 0.5446 - val_accuracy: 0.7635 - val_loss: 0.4967 - learning_rate: 1.0000e-04
# Epoch 3/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7436 - loss: 0.5209
# Epoch 3: val_loss improved from 0.49669 to 0.46250, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
#
# Epoch 3: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 51s 55ms/step - accuracy: 0.7497 - loss: 0.5142 - val_accuracy: 0.7817 - val_loss: 0.4625 - learning_rate: 1.0000e-04
# Epoch 4/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7596 - loss: 0.4930
# Epoch 4: val_loss improved from 0.46250 to 0.45904, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
#
# Epoch 4: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 51s 55ms/step - accuracy: 0.7593 - loss: 0.4939 - val_accuracy: 0.7825 - val_loss: 0.4590 - learning_rate: 1.0000e-04
# Epoch 5/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7694 - loss: 0.4815
# Epoch 5: val_loss improved from 0.45904 to 0.43859, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
#
# Epoch 5: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 51s 54ms/step - accuracy: 0.7680 - loss: 0.4812 - val_accuracy: 0.7930 - val_loss: 0.4386 - learning_rate: 1.0000e-04
# Epoch 6/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7727 - loss: 0.4737
# Epoch 6: val_loss did not improve from 0.43859
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7734 - loss: 0.4751 - val_accuracy: 0.7738 - val_loss: 0.4621 - learning_rate: 1.0000e-04
# Epoch 7/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7757 - loss: 0.4686
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 7: val_loss did not improve from 0.43859
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7786 - loss: 0.4655 - val_accuracy: 0.7884 - val_loss: 0.4406 - learning_rate: 1.0000e-04
# Epoch 8/30
# 934/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7753 - loss: 0.4645
# Epoch 8: val_loss did not improve from 0.43859
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7769 - loss: 0.4641 - val_accuracy: 0.7861 - val_loss: 0.4418 - learning_rate: 5.0000e-05
# Epoch 9/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7823 - loss: 0.4574
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 9: val_loss did not improve from 0.43859
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7816 - loss: 0.4604 - val_accuracy: 0.7799 - val_loss: 0.4493 - learning_rate: 5.0000e-05
# Epoch 10/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7812 - loss: 0.4543
# Epoch 10: val_loss improved from 0.43859 to 0.43095, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
#
# Epoch 10: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 51s 54ms/step - accuracy: 0.7798 - loss: 0.4577 - val_accuracy: 0.7932 - val_loss: 0.4309 - learning_rate: 2.5000e-05
# Epoch 11/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7832 - loss: 0.4551
# Epoch 11: val_loss did not improve from 0.43095
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7821 - loss: 0.4578 - val_accuracy: 0.7852 - val_loss: 0.4402 - learning_rate: 2.5000e-05
# Epoch 12/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7830 - loss: 0.4534
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 12: val_loss did not improve from 0.43095
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.7821 - loss: 0.4549 - val_accuracy: 0.7885 - val_loss: 0.4361 - learning_rate: 2.5000e-05
# Epoch 13/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7779 - loss: 0.4579
# Epoch 13: val_loss improved from 0.43095 to 0.42328, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
#
# Epoch 13: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7798 - loss: 0.4559 - val_accuracy: 0.7996 - val_loss: 0.4233 - learning_rate: 1.2500e-05
# Epoch 14/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7806 - loss: 0.4576
# Epoch 14: val_loss improved from 0.42328 to 0.42047, saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
#
# Epoch 14: finished saving model to /kaggle/working/resnet50_original_noaug_cv_fold_5.keras
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.7817 - loss: 0.4551 - val_accuracy: 0.8021 - val_loss: 0.4205 - learning_rate: 1.2500e-05
# Epoch 15/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7858 - loss: 0.4469
# Epoch 15: val_loss did not improve from 0.42047
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7823 - loss: 0.4533 - val_accuracy: 0.7926 - val_loss: 0.4308 - learning_rate: 1.2500e-05
# Epoch 16/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7896 - loss: 0.4471
# Epoch 16: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 16: val_loss did not improve from 0.42047
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7840 - loss: 0.4542 - val_accuracy: 0.7870 - val_loss: 0.4378 - learning_rate: 1.2500e-05
# Epoch 17/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7866 - loss: 0.4490
# Epoch 17: val_loss did not improve from 0.42047
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7843 - loss: 0.4533 - val_accuracy: 0.7909 - val_loss: 0.4322 - learning_rate: 6.2500e-06
# Epoch 18/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7795 - loss: 0.4550
# Epoch 18: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 18: val_loss did not improve from 0.42047
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7839 - loss: 0.4526 - val_accuracy: 0.7955 - val_loss: 0.4278 - learning_rate: 6.2500e-06
# Epoch 19/30
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7846 - loss: 0.4534
# Epoch 19: val_loss did not improve from 0.42047
# 935/935 ━━━━━━━━━━━━━━━━━━━━ 49s 53ms/step - accuracy: 0.7852 - loss: 0.4525 - val_accuracy: 0.7969 - val_loss: 0.4267 - learning_rate: 3.1250e-06
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Fold 5 completed in 16.13 minutes

# %%
fold_results_df = pd.DataFrame(fold_results)

display(
    fold_results_df.round(4)
)

print(
    "\nMean validation accuracy:",
    round(fold_results_df["Validation Accuracy"].mean(), 4)
)

print(
    "Validation accuracy standard deviation:",
    round(fold_results_df["Validation Accuracy"].std(), 4)
)

print(
    "Mean validation ROC-AUC:",
    round(fold_results_df["ROC-AUC"].mean(), 4)
)
# Out:
#    Fold  Epochs Trained  Best Epoch  Training Loss  Training Accuracy  \
# 0     1              12           7         0.4656             0.7753
# 1     2              13           8         0.4606             0.7776
# 2     3              20          15         0.4563             0.7793
# 3     4              17          12         0.4478             0.7881
# 4     5              19          14         0.4551             0.7817
#
#    Validation Loss  Validation Accuracy  Precision  Recall  F1-score  ROC-AUC  \
# 0           0.4177               0.8071     0.8761  0.8479    0.8617   0.8721
# 1           0.4103               0.8110     0.8796  0.8497    0.8644   0.8805
# 2           0.4338               0.7947     0.8971  0.8024    0.8471   0.8782
# 3           0.4207               0.8043     0.8969  0.8181    0.8556   0.8847
# 4           0.4205               0.8021     0.8949  0.8169    0.8541   0.8847
#
#    Training Minutes
# 0           10.2593
# 1           11.0451
# 2           16.9068
# 3           14.3903
# 4           16.1338
# Mean validation accuracy: 0.8038
# Validation accuracy standard deviation: 0.0061
# Mean validation ROC-AUC: 0.88

# %%
summary_columns = [
    "Training Loss",
    "Training Accuracy",
    "Validation Loss",
    "Validation Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "ROC-AUC",
    "Training Minutes"
]

cv_summary = pd.DataFrame({
    "Mean": fold_results_df[
        summary_columns
    ].mean(),

    "Standard Deviation": fold_results_df[
        summary_columns
    ].std()
})

display(cv_summary.round(4))
# Out:
#                         Mean  Standard Deviation
# Training Loss         0.4571              0.0066
# Training Accuracy     0.7804              0.0049
# Validation Loss       0.4206              0.0085
# Validation Accuracy   0.8038              0.0061
# Precision             0.8889              0.0102
# Recall                0.8270              0.0208
# F1-score              0.8566              0.0068
# ROC-AUC               0.8800              0.0052
# Training Minutes     13.7471              2.9815

# %%
test_probabilities_cv = np.mean(
    np.vstack(fold_test_probabilities),
    axis=0
)

test_predictions_cv = (
    test_probabilities_cv >= 0.5
).astype(int)

true_test_labels = test_df[
    "label"
].to_numpy()

print("Test images:", len(true_test_labels))
print("Fold prediction arrays:", len(fold_test_probabilities))
print("Ensemble probabilities:", len(test_probabilities_cv))
print("Ensemble predictions:", len(test_predictions_cv))

print(
    "First ensemble probabilities:",
    test_probabilities_cv[:10].round(4)
)
# Out:
# Test images: 6600
# Fold prediction arrays: 5
# Ensemble probabilities: 6600
# Ensemble predictions: 6600
# First ensemble probabilities: [0.8948 0.6544 0.7874 0.6688 0.9062 0.9188 0.8622 0.4015 0.9501 0.9216]

# %%
from sklearn.metrics import log_loss

test_loss_cv = log_loss(
    true_test_labels,
    test_probabilities_cv
)

test_accuracy_cv = accuracy_score(
    true_test_labels,
    test_predictions_cv
)

print("Test Loss:", round(test_loss_cv, 4))
print("Test Accuracy:", round(test_accuracy_cv, 4))
# Out:
# Test Loss: 0.4241
# Test Accuracy: 0.8045

# %%
from sklearn.metrics import classification_report

test_precision_cv = precision_score(
    true_test_labels,
    test_predictions_cv
)

test_recall_cv = recall_score(
    true_test_labels,
    test_predictions_cv
)

test_f1_cv = f1_score(
    true_test_labels,
    test_predictions_cv
)

test_roc_auc_cv = roc_auc_score(
    true_test_labels,
    test_probabilities_cv
)

print("Test Loss:", round(test_loss_cv, 4))
print("Accuracy:", round(test_accuracy_cv, 4))
print("Precision:", round(test_precision_cv, 4))
print("Recall:", round(test_recall_cv, 4))
print("F1-score:", round(test_f1_cv, 4))
print("ROC-AUC:", round(test_roc_auc_cv, 4))

print("\nClassification Report:\n")
print(
    classification_report(
        true_test_labels,
        test_predictions_cv,
        target_names=["NonDemented", "Demented"],
        digits=4
    )
)
# Out:
# Test Loss: 0.4241
# Accuracy: 0.8045
# Precision: 0.8873
# Recall: 0.8297
# F1-score: 0.8576
# ROC-AUC: 0.8762
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#  NonDemented     0.6416    0.7432    0.6887      1920
#     Demented     0.8873    0.8297    0.8576      4680
#
#     accuracy                         0.8045      6600
#    macro avg     0.7645    0.7865    0.7731      6600
# weighted avg     0.8159    0.8045    0.8084      6600

# %%
from sklearn.metrics import confusion_matrix

confusion_cv = confusion_matrix(
    true_test_labels,
    test_predictions_cv
)

plt.figure(figsize=(7, 5))

sns.heatmap(
    confusion_cv,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["NonDemented", "Demented"],
    yticklabels=["NonDemented", "Demented"]
)

plt.title(
    "ResNet50 Original No Augmentation\n"
    "5-Fold CV Ensemble Confusion Matrix"
)
plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve

false_positive_rate, true_positive_rate, thresholds = roc_curve(
    true_test_labels,
    test_probabilities_cv
)

plt.figure(figsize=(7, 5))

plt.plot(
    false_positive_rate,
    true_positive_rate,
    linewidth=2,
    label=(
        "Original No Augmentation "
        f"(AUC = {test_roc_auc_cv:.4f})"
    )
)

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--",
    color="gray",
    label="Random Classifier"
)

plt.title(
    "ResNet50 Original No Augmentation\n"
    "5-Fold CV Ensemble ROC Curve"
)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
mean_validation_accuracy = fold_results_df[
    "Validation Accuracy"
].mean()

plt.figure(figsize=(8, 5))

bars = plt.bar(
    fold_results_df["Fold"],
    fold_results_df["Validation Accuracy"],
    color="steelblue"
)

plt.axhline(
    mean_validation_accuracy,
    color="red",
    linestyle="--",
    label=f"Mean = {mean_validation_accuracy:.4f}"
)

for bar, value in zip(
    bars,
    fold_results_df["Validation Accuracy"]
):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        value + 0.003,
        f"{value:.4f}",
        ha="center"
    )

plt.ylim(0, 1)
plt.title("Validation Accuracy Across Five Folds")
plt.xlabel("Fold")
plt.ylabel("Validation Accuracy")
plt.xticks(fold_results_df["Fold"])
plt.legend()
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(
    2,
    3,
    figsize=(15, 9),
    sharey=True
)

axes = axes.flatten()

for index, (fold, fold_history) in enumerate(
    fold_histories.items()
):
    ax = axes[index]

    epochs = np.arange(1, len(fold_history) + 1)
    best_epoch_fold = fold_history["val_loss"].idxmin() + 1
    best_val_loss = fold_history["val_loss"].min()

    ax.plot(
        epochs,
        fold_history["loss"],
        color="steelblue",
        linewidth=2,
        label="Training Loss"
    )

    ax.plot(
        epochs,
        fold_history["val_loss"],
        color="darkorange",
        linewidth=2,
        label="Validation Loss"
    )

    ax.axvline(
        best_epoch_fold,
        color="red",
        linestyle="--",
        alpha=0.8,
        label=f"Best Epoch: {best_epoch_fold}"
    )

    ax.scatter(
        best_epoch_fold,
        best_val_loss,
        color="red",
        s=60,
        zorder=5
    )

    ax.set_title(f"Fold {fold}")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.grid(alpha=0.3)
    ax.legend(fontsize=8)

# Remove the unused sixth graph
fig.delaxes(axes[5])

plt.suptitle(
    "ResNet50 Original Without Augmentation\n"
    "Training and Validation Loss by Fold",
    fontsize=16
)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 7))

colors = [
    "tab:blue",
    "tab:green",
    "tab:purple",
    "tab:pink",
    "tab:olive"
]

for (fold, fold_history), color in zip(
    fold_histories.items(),
    colors
):
    epochs = range(1, len(fold_history) + 1)

    plt.plot(
        epochs,
        fold_history["loss"],
        color=color,
        linewidth=2,
        label=f"Fold {fold} Training"
    )

    plt.plot(
        epochs,
        fold_history["val_loss"],
        color=color,
        linestyle="--",
        linewidth=2,
        label=f"Fold {fold} Validation"
    )

plt.title(
    "ResNet50 Original Without Augmentation\n"
    "Training and Validation Loss Across All Five Folds"
)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(
    ncol=2,
    fontsize=9,
    loc="upper right"
)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Individual graph for each fold
fig, axes = plt.subplots(
    2,
    3,
    figsize=(15, 9),
    sharey=True
)

axes = axes.flatten()

for index, (fold, fold_history) in enumerate(
    fold_histories.items()
):
    ax = axes[index]

    epochs = np.arange(1, len(fold_history) + 1)
    best_epoch_fold = fold_history["val_loss"].idxmin() + 1

    ax.plot(
        epochs,
        fold_history["accuracy"],
        color="steelblue",
        linewidth=2,
        label="Training Accuracy"
    )

    ax.plot(
        epochs,
        fold_history["val_accuracy"],
        color="darkorange",
        linewidth=2,
        label="Validation Accuracy"
    )

    ax.axvline(
        best_epoch_fold,
        color="red",
        linestyle="--",
        label=f"Best Epoch: {best_epoch_fold}"
    )

    ax.set_title(f"Fold {fold}")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Accuracy")
    ax.set_ylim(0.55, 0.85)
    ax.grid(alpha=0.3)
    ax.legend(fontsize=8)

fig.delaxes(axes[5])

plt.suptitle(
    "ResNet50 Original Without Augmentation\n"
    "Training and Validation Accuracy by Fold",
    fontsize=16
)

plt.tight_layout()
plt.show()


# All folds together
plt.figure(figsize=(12, 7))

colors = [
    "tab:blue",
    "tab:green",
    "tab:purple",
    "tab:pink",
    "tab:olive"
]

for (fold, fold_history), color in zip(
    fold_histories.items(),
    colors
):
    epochs = range(1, len(fold_history) + 1)

    plt.plot(
        epochs,
        fold_history["accuracy"],
        color=color,
        linewidth=2,
        label=f"Fold {fold} Training"
    )

    plt.plot(
        epochs,
        fold_history["val_accuracy"],
        color=color,
        linestyle="--",
        linewidth=2,
        label=f"Fold {fold} Validation"
    )

plt.title(
    "ResNet50 Original Without Augmentation\n"
    "Training and Validation Accuracy Across All Five Folds"
)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(ncol=2, fontsize=9)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
metric_names = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "ROC-AUC"
]

metric_values = [
    test_accuracy_cv,
    test_precision_cv,
    test_recall_cv,
    test_f1_cv,
    test_roc_auc_cv
]

plt.figure(figsize=(9, 5))

bars = plt.bar(
    metric_names,
    metric_values,
    color=[
        "steelblue",
        "teal",
        "darkorange",
        "purple",
        "seagreen"
    ]
)

plt.ylim(0, 1)
plt.title(
    "ResNet50 Original Without Augmentation\n"
    "5-Fold CV Ensemble Test Metrics"
)
plt.ylabel("Score")
plt.grid(axis="y", alpha=0.3)

for bar, value in zip(bars, metric_values):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        value + 0.015,
        f"{value:.4f}",
        ha="center"
    )

plt.tight_layout()
plt.show()

# %%
sample_indices = np.random.default_rng(SEED).choice(
    len(test_df),
    size=12,
    replace=False
)

plt.figure(figsize=(16, 12))

for position, index in enumerate(sample_indices, start=1):
    image = tf.keras.utils.load_img(
        test_df.iloc[index]["filepath"],
        target_size=IMG_SIZE
    )

    actual = true_test_labels[index]
    predicted = test_predictions_cv[index]
    probability = test_probabilities_cv[index]

    actual_name = (
        "Demented" if actual == 1
        else "NonDemented"
    )

    predicted_name = (
        "Demented" if predicted == 1
        else "NonDemented"
    )

    title_color = (
        "green" if actual == predicted
        else "red"
    )

    plt.subplot(3, 4, position)
    plt.imshow(image)
    plt.title(
        f"Actual: {actual_name}\n"
        f"Predicted: {predicted_name}\n"
        f"Dementia probability: {probability:.3f}",
        color=title_color,
        fontsize=10
    )
    plt.axis("off")

plt.suptitle(
    "ResNet50 Original Without Augmentation\n"
    "5-Fold CV Ensemble Sanity Test",
    fontsize=16
)

plt.tight_layout()
plt.show()

# %%
test_results_df = pd.DataFrame([{
    "Experiment": (
        "ResNet50 Original Without Augmentation "
        "+ 5-Fold CV"
    ),
    "Model": "ResNet50",
    "Preprocessing": "None",
    "Augmentation": "No",
    "Cross-Validation": "5-Fold",
    "Test Loss": test_loss_cv,
    "Accuracy": test_accuracy_cv,
    "Precision": test_precision_cv,
    "Recall": test_recall_cv,
    "F1-score": test_f1_cv,
    "ROC-AUC": test_roc_auc_cv
}])

fold_results_df.to_csv(
    "/kaggle/working/"
    "resnet50_original_noaug_cv_fold_results.csv",
    index=False
)

cv_summary.to_csv(
    "/kaggle/working/"
    "resnet50_original_noaug_cv_summary.csv"
)

test_results_df.to_csv(
    "/kaggle/working/"
    "resnet50_original_noaug_cv_test_results.csv",
    index=False
)

for fold, fold_history in fold_histories.items():
    fold_history.to_csv(
        f"/kaggle/working/"
        f"resnet50_original_noaug_cv_fold_{fold}_history.csv",
        index=False
    )

display(test_results_df.round(4))

print("Saved:")
print("- Fold results CSV")
print("- Mean and standard-deviation summary CSV")
print("- Ensemble test-results CSV")
print("- Five training-history CSV files")
print("- Five best fold models")
# Out:
#                                           Experiment     Model Preprocessing  \
# 0  ResNet50 Original Without Augmentation + 5-Fol...  ResNet50          None
#
#   Augmentation Cross-Validation  Test Loss  Accuracy  Precision  Recall  \
# 0           No           5-Fold     0.4241    0.8045     0.8873  0.8297
#
#    F1-score  ROC-AUC
# 0    0.8576   0.8762
# Saved:
# - Fold results CSV
# - Mean and standard-deviation summary CSV
# - Ensemble test-results CSV
# - Five training-history CSV files
# - Five best fold models
